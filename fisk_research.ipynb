# %% [markdown]
# # Cleaned Parsing Functions

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import re
import dateutil.parser
import datetime
import json
from ast import literal_eval

# %% [markdown]
# ## Overview

# %% [markdown]
# Our goal is to extract relevant information on every article tagged with the `Codingbootcamp` tag.
# We accomplish this in three steps:
# 1. Iterate through each page of the archive for this tag.
# 2. On each date page (such as 2018/01/02), extract the urls for all links that correspond to articles published on that date tagged with `Codingbootcamp` (don't extract "Home", "signup" links etc).
# 3. On each url, call the single article parsing function to extract author, author_bio, title, publish date, publisher, and article text.

# %% [markdown]
# ## Get HTML Function
# **Base Source**: https://realpython.com/python-web-scraping-practical-introduction/
# **Update10/1/18**: This code originated from this tutorial but was later adapted in order complete step 3 - to get all articles tagged with `Codingbootcamp`.
# I added a second get html function that checked whether the web browser redirected you at some point when attempting to access the html at the provided link. This was necessary because when you attempted to access a page of the archive that didn't exist - such as attempting to access `archive/2013/03/02`, you are instead redirected back to the year or month page. In those situations, I didn't want to re-parse the articles on the main page, which would have been redundant parsing (and extra time in an already long function, and instead didn't parse a page that had been redirected.
# I had to keep this in a seperate function, because for certain single article urls, like "https://medium.freecodecamp.org/5-key-learnings-from-the-post-bootcamp-job-search-9a07468d2331" were redirected in the retreival process (I am not sure why). I attempted to come up with a elegant solution using response object attributes that would differentiate between article redirects and archive redirects, but was unable to do so.
# So the function that retrieves the html for articles doesn't check for redirects, but the function that retrieves archive page html does check for redirects.

# %%
# Define get function to get raw HTML
def simple_get_article(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        #closing ensures any network resources are freed when out of scope - good practice
        with closing(get(url, stream=True)) as resp: 
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# Define get function to get raw HTML from the archive pages, with a twist.
def simple_get_archive(url):
    """
    Retrieves the raw html of a page in the `Codingbootcamp` tag archive (https://medium.com/tag/codingbootcamp/archive).
    But some pages of the archive don't exist (like 2013/01/02) because no stories were published on that date. 
    If you attempt to access these nonexistent urls, you are redirected to the main year or month page.
    We don't want to re-parse those pages (redundant code), so our hack-y solution is to check to see if the HTML response
    object has a redirect (302 status code) in its history. 
    This is defined as a separate function, because some of the article urls are redirected (I am not sure why), and I couldn't 
    come up with a clean solution that separates article redirection vs archive redirection. 
    """
    try:
        #closing ensures any network resources are freed when out of scope - good practice
        with closing(get(url, stream=True)) as resp: 
            if is_redirect(resp):
                return "redirect"
            elif is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
    
# I added this helper function to check if the HTML response returned by the browser had been redirected at some point
# See http://docs.python-requests.org/en/v0.10.6/api/ for docs on history attribute
def is_redirect(resp):
    """
    Returns True if the resp had been redirected at some point in the retrieval process due to nonexistent url, 
    False otherwise. 
    Arguments: a HTML response object
    """
    resp_history = resp.history
    if resp_history: #not empty - some things happend before response was returned
        # I specifically want to check for redirects (status code 302)
        statuses = [h.status_code==302 for h in resp_history]
        # Are there any true in the above list comp? Then something was redirected. 
        return np.any(statuses)
    else:
        return False
    
def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %% [markdown]
# ## Single Article Info Parsing

# %% [markdown]
# The following functions return information parsed from a single article on Medium.

# %%
def get_author(parsed_html):
    """Parses the author name from a Medium article. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        the author name as a string or None if author tag not present
    """
    author = parsed_html.find('meta', property="author")
    return author['content'] if author else None

def get_author_bio(parsed_html):
    """Parses the author's bio/description from a Medium article. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        the author bio/description as a string if it exists, and None otherwise
    """
    bios = parsed_html.find_all('div', class_="ui-caption ui-xs-clamp2 postMetaInline")
    # If bios is empty, that means there is no author bio for article, and the [0]  will error so we need to explicityly
    # check and return None if no author bio
    return bios[0].text if bios else None

def get_title(parsed_html):
    """Parses the title of a Medium article.
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        the title of the article as a string or None if title tag not present
    """
    title = parsed_html.find('meta', property='og:title')
    return title['content'] if title else None

def get_raw_publish_date(parsed_html):
    """Parses the date a Medium article was published. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        a raw/uncleaned publish date, which looks like '2016-11-19T16:48:30.365Z', or None if tag not present
    """
    date = parsed_html.find('meta', property='article:published_time')
    return date['content'] if date else None

def get_article_publisher(parsed_html):
    """Parses the article's publisher from a Medium article. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Notes:
        The publisher is encoded as "https://facebook.com/publisher" so I extract just the publisher name.
        Not all articles have a verified publisher - like if it's just the author's personal blog - so publisher is
        just "medium" in that case
    Returns:
        If article is hosted on verified publisher, returns publisher name as string
        If article is on personal blog, returns "medium" as a string. 
        If publisher tag doesn't exist, returns None
        
    """
    long_publisher = parsed_html.find("meta", property='article:publisher')
    return long_publisher['content'].split("/")[3] if long_publisher else None

def get_raw_article_text(parsed_html):
    """Extracts out the text/content of the Medium article.
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns:
        a raw/uncleaned string of text or None if tag is not present.
        The string is considered "raw" because there are some weird characters that are remants
        of header formatting and the like.
    """
    text = parsed_html.find_all('div', class_='postArticle-content')
    return text[0].text if text else None

def clean_text(text):
    """takes a string of text
    removes \xa0 and \u200a that are randomly splattered throughout text
    adds spaces after punctuation that appeared to be missing
    splits all words where a capital letter is in the middle of a word and puts a space in front of it and removes double spaces
    """
    if text:
        cleaned_text = text.replace("\xa0", " ").replace("\u200a", " ")
        cleaned_text = re.sub(r'(?<=[.,])(?=[^\s])', r' ', cleaned_text)
        cleaned_text = re.sub(r'([A-Z])', r' \1', cleaned_text).lstrip().replace("  ", " ")
        return cleaned_text
    else:
        # text is a None object which you can't use regex on.
        return text

def clean_date(date):
    """takes a string in RFC 339 format ('Y-M-D"T"H:M:S.MS"Z"')
    returns a string of format ('Y-M-D H:M:S')
    """
    if date:
        date = dateutil.parser.parse(date)
        date = date.strftime("%Y-%m-%d %H:%M:%S")
        return date
    else:
        # Date is a None object and you can't parse it
        return date
    
def get_tags(parsed_html):
    script_html = parsed_html.find("script", type='application/ld+json')
    script_data = json.loads(script_html.text)
    keywords_list = script_data['keywords']
    tags = []
    for elem in keywords_list:
        if elem.startswith("Tag:"):
            tags.append(elem[4:])
    return tags

def get_url(parsed_html):
    url = parsed_html.find("meta", property="al:web:url")
    return url["content"]


def get_all_article_info(article_url):
    """Parses a Medium article to get all needed information about author and story.
    Arguments:
        article_url: String of url for article to parse
    Returns:
        list of [author, author_bio, title, date, publisher article_text], where each component is a string or None
    """
    raw_html = simple_get_article(article_url)
    parsed_html = BeautifulSoup(raw_html, 'html.parser')
    author = get_author(parsed_html)
    author_bio = get_author_bio(parsed_html)
    title = get_title(parsed_html)
    raw_date = get_raw_publish_date(parsed_html)
    cleaned_date = clean_date(raw_date)
    publisher = get_article_publisher(parsed_html)
    raw_text = get_raw_article_text(parsed_html)
    cleaned_text = clean_text(raw_text)
    tags = get_tags(parsed_html)
    url = get_url(parsed_html)
    return [author, author_bio, title, cleaned_date, publisher, cleaned_text, tags, url]

# %%
## working on getting the tags of the article
# article_url = "https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38"
# raw_html = simple_get_article(article_url)
# parsed_html = BeautifulSoup(raw_html, 'html.parser')
# # print(parsed_html)
# script_html = parsed_html.find("script", type='application/ld+json')
# long_publisher = parsed_html.find("meta", property='article:publisher')['content']
# # print(long_publisher)
# ## extract content of script https://stackoverflow.com/questions/26192727/extract-content-of-script-with-beautifulsoup
# script_data = json.loads(script_html.text)
# keywords_list = script_data['keywords']
# tags = []
# for elem in keywords_list:
#     if elem.startswith("Tag:"):
#         tags.append(elem[4:])
# # print(tags)

# def get_tags(parsed_html):
#     script_html = parsed_html.find("script", type='application/ld+json')
#     script_data = json.loads(script_html.text)
#     keywords_list = script_data['keywords']
#     tags = []
#     for elem in keywords_list:
#         if elem.startswith("Tag:"):
#             tags.append(elem[4:])
#     return tags

# get_tags(parsed_html)

# %%
## working on getting the url
# article_url = "https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38"
# raw_html = simple_get_article(article_url)
# parsed_html = BeautifulSoup(raw_html, 'html.parser')
# def get_url(parsed_html):
#     url = parsed_html.find("meta", property="al:web:url")
#     return url["content"]
# get_url(parsed_html)

# %% [markdown]
# ### Single Article Example Usage

# %%
test_url_1 = "https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38"
get_all_article_info(test_url_1)
# Out:
# ['Chris Lee',
#  None,
#  "We're Not a Bootcamp – Launch School – Medium",
#  '2018-08-01 01:48:19',
#  'medium',
#  'We’re Not a Bootcamp We’re Something Unique, and Uniquely Effective Photo by Kyle Johnson on Unsplash One of the things about operating in a crowded marketplace is that you tend to get lumped in with the biggest names and most common stereotypes. In the programming education space, that means the now familiar label of “bootcamp. ” I often see people refer to Launch School as a “coding bootcamp, ” which may seem like a reasonable shortcut for helping people understand what we do; however, it fails to capture what makes us special. When I talk about Launch School and what we are trying to achieve, I don’t use the word “bootcamp. ” We are an online school for developers, but more than that, we are a school with an opinionated pedagogy that focuses on fundamentals first with the goal of building skills that last a career. So, why do I steer clear of the “bootcamp” label? To put it simply, I don’t believe that it accurately describes our model. Neither our methodology nor our curriculum reflect those of most coding “bootcamps, ” and to be frank, nor do our results. Graduates of our Capstone program are getting jobs with an average salary around $110, 000, as compared to graduates of even the best bootcamps, who in the same markets are averaging salaries around $85, 000. Why is that? The reason is that we are doing something different than what the bootcamps are doing. Launch School is the only online school for developers with a pedagogy that explicitly revolves around mastery-based learning. Plenty of schools, some bootcamps included, talk about the importance of mastering the fundamentals, but we are the only one that is actually putting that claim into practice. And we do this because we firmly believe that mastering fundamentals, first and foremost, is the best way to launch a lifelong career as a software developer. Our mission is to help our students get not just any job, but top jobs, at top companies. Of course, every school and bootcamp out there makes similar claims. So today I want to talk about how Launch School is different and explain why our philosophy leads to better outcomes. The Bootcamp Model Photo by My Photo Journeys on Flickr. C C license. In order to set the stage for understanding Launch School’s philosophy, perhaps we should first take a moment to understand our point of comparison: the bootcamp model. The name of this model itself provides us with a useful starting point. A “bootcamp, ” by common definition, is a short but intense period of training meant to shock the system of people who go through it. The goal is to quickly indoctrinate participants into a new way of thinking and provide them all at once with everything they need to be successful. Most coding bootcamps operate in a roughly analogous fashion, albeit from two starting points. In one model, a bootcamp will accept any and all students who want to join. In the other, bootcamps accept only the “best” students. In both cases though, students enter the program, undergo 8, or 12, or 16, or even 24, weeks of intense instruction, and then exit the program with the hope that they know enough to start going after jobs. For the more selective bootcamps, the hope is that starting with the “best” students will result in a higher percentage of successful graduates; however, even this is an implicit acknowledgement that the model doesn’t work for everyone. In many ways, the bootcamp model is not so very different from the factory-style education model practiced by most of our broader education system. That is, students come in, go through some predefined series of steps over some predefined and non-negotiable schedule, and then come out, ready or not. But what happens when a student moves between steps too soon? What happens when a student “graduates” (meaning primarily that they made it to the end of the program) but hasn’t yet had time to put down the necessary intellectual roots? The problem with the bootcamp model is that it doesn’t provide most lea ...
#  ['Programming',
#   'Coding',
#   'Codingbootcamp',
#   'Learning To Code',
#   'Launch School'],
#  'https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38']

# %% [markdown]
# ### Get all open post links from a page

# %%
def get_all_open_post_links(parsed_html):
    """Retrieves all links on a page that open to an article (does not return "home", "sign up" links etc).
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Notes:
        All links on a page that have the data-attribute 'open-post' are the types of links we want.
        find_all returns a special BeautifulSoup object so I need to extract the string url.
        I think there are muliple links for each post (like the title and "read more"), so returning array 
        has duplicates
    Returns:
        List of link strings
    """
    def href_open_post_data_action(tag):
        """Helper parsing function that checks to see if an "a" tag is an href with an 'open-post' data action.
        Arguments:
            tag: All html tags like <a>, <div> that BeautifulSoup has extracted
        Returns:
            true if tag has href and 'open-post' data-action attribute, false otherwise
        """
        return tag.has_attr('href') and tag.get('data-action') == 'open-post'
    
    link_objects =  parsed_html.find_all(href_open_post_data_action)
    return [link.get('href') for link in link_objects] #retrieves the string url from link object

# %% [markdown]
# The above function is the "middle level" function in the grand scheme of our parsing.
# First, we defined the function that parses information for a single article.
# The next step is to retrieve all the links to articles on a web page (like the web page returned by searching "coding bootcamp" for example), and then call our single article parsing function on each link we extracted from the page.
# Note - the name is "open post" links because there are a ton of links on a webpage - to "home", to "sign-up", to "search" etc. We are only interested in extracting the links that correspond to articles about coding bootcamps.
# After inspecting the source html, I discovered that all links that open to coding bootcamp articles have the attribute "data-action" set to "open-post" within the html `<a href>` tag. So this function ensures that it only extracts the links we want.

# %% [markdown]
# ## Iterate Through All Dates in Archive

# %% [markdown]
# The next step is to define a function that will iterate through each "date" page in the archive, gather all the open post links for each "date" page (i.e. all the story links), and then call the single article parser on each link.
# **NOTE**: The following function is currently defined such that it will *ONLY* work on the archive for the `Codingbootcamp` (https://medium.com/tag/codingbootcamp/archive) because currently it operates on the assumption that the years 2013 and 2014 have so few articles that they are not seperated by month or day, only year.

# %%
def format_dates_for_url(integer_date):
    """
    Formats dates to enter into the archive url, which requires numbers < 10 to be encoded with a "0" in front,
    but Python doesn't allow 01 as an integer. 
    """
    if integer_date < 10:
        return str(0) + str(integer_date)
    else:
        return str(integer_date)
def get_specific_Codingbootcamp_links():
    # For current range of years available
    years = range(2013, 2019)
    months_w_o_zero_in_front = range(1, 13)
    days_w_o_zero = range(1, 32)
    base_url = "https://medium.com/tag/codingbootcamp/archive"
    # Collector variable to story all story urls
    story_links = []
    for year in years:
        # These years don't have month, day subdivisions so to prevent redundant parsing, 
        # just parse the base year and its links.
        if year == 2013 or year == 2014:
            # 
            url = base_url + "/" + format_dates_for_url(year)
            raw_year_html = simple_get_archive(url)
            # If raw_year_html is None, can't parse it so skip
            if not raw_year_html:
                break
            parsed_year_html = BeautifulSoup(raw_year_html, 'html.parser')
            links = get_all_open_post_links(parsed_year_html)
            #use extend instead of append because just want to add elements, not create nested lists.
            story_links.extend(links) 
        else:
            for month in months_w_o_zero_in_front:
                for day in days_w_o_zero:
                    url = base_url + "/" + format_dates_for_url(year) + format_dates_for_url(month) + "/" + format_dates_for_url(day)
                    raw_day_html = simple_get_archive(url)
                    # 2015, 2016, 2017, 2018 have some dates with no stories, so GET requests are redirected
                    # and we don't want to parse stuff we already did.
                    if raw_day_html == "redirect":
                        #skip the redirected day - advance in for loop
                        break
                    # If raw_day_html is None, can't parse it so skip
                    elif not raw_day_html:
                        break
                    parsed_day_html = BeautifulSoup(raw_day_html, 'html.parser')
                    links = get_all_open_post_links(parsed_day_html)
                    #use extend instead of append because just want to add elements, not create nested lists.
                    story_links.extend(links)
    # Create a set of links to remove duplicates and then turn back into a list (better data structure)
    return list(set(story_links))

# %% [markdown]
# ### Collect Text Data

# %%
# List of urls for all stories tagged with `Codingbootcamp`
story_links = get_specific_Codingbootcamp_links()

# %%
# Get all info like article, publisher, etc for each url gathered above
# THIS CELL TAKES FOREVER BE WARNED - DO NOT CLOSE COMPUTER WHILE RUNNING ELSE THE CONNECTION BREAKS
story_info_list = []
for url in story_links:
    story_info_list.append(get_all_article_info(url))

# %%
column_names = ["author", "author_bio", "title", "date", "publisher", "text", "tags", "url"]
Codingbootcamp_info = pd.DataFrame(story_info_list, columns = column_names)

# %%
Codingbootcamp_info

# %%
#Convert to csv so I don't have to run the collection function again - it takes FOREVER
Codingbootcamp_info.to_csv("codingbootcamp_articles_info.csv", index=False)

# %%
Codingbootcamp_info = pd.read_csv("codingbootcamp_articles_info.txt")

#make sure that the tag column is not a string but a list
Codingbootcamp_info["tags"] = Codingbootcamp_info["tags"].apply(literal_eval)
Codingbootcamp_info
# Out:
#                      author  \
# 0            Gregorio Rojas
# 1               Emily Deans
# 2            Verity Honebon
# 3                Emily Chai
# 4           Jackson McGehee
# 5              Bree Jackson
# 6             Sara Jo Helba
# 7             Emmanuel Amon
# 8                 sam foong
# 9           Joseph Cardillo
# 10                 Joe Andy
# 11           Le Wagon Tokyo
# 12              Emily Deans
# 13              Gabe Wright
# 14         chibueze ukaegbu
# 15             Zaynaib Giwa
# 16           Rhys Woodberry
# 17             Angela Wolff
# 18           Monica Kosciuk
# 19              Jacob Moore
# 20           Taylor Edwards
# 21               Mike Brave
# 22            it’s jennilyn
# 23          Brigit Rossbach
# 24            Timika Downes
# 25           Sam Pellegrene
# 26             Hack Reactor
# 27               KeepCoding
# 28            Kalen Hammann
# 29             Yonko Kilasi
# ...                     ...
# 1006        Code Collective
# 1007           Rithm School
# 1008             KeepCoding
# 1009              AngelHack
# 1010          Clint Schmidt
# 1011         Verity Honebon
# 1012               CodeClan
# 1013          Nat Villasana
# 1014  Sabio Coding Bootcamp
# 1015           Hack Reactor
# 1016         Anthony Jarina
# 1017         Jennifer Bland
# 1018           Hack Reactor
# 1019          Mario Posadas
# 1020         Gregorio Rojas
# 1021          Caleb Harnell
# 1022  Sabio Coding Bootcamp
# 1023  Sabio Coding Bootcamp
# 1024            Kenneth Teh
# 1025                conshus
# 1026       Aaron Blackshear
# 1027            Nabil Yafai
# 1028            Emily Deans
# 1029                  J.Lim
# 1030       Chris Fellingham
# 1031  Nicholas Vincent-Hill
# 1032        Charles Clemens
# 1033                conshus
# 1034       Lauren Greenberg
# 1035            Emily Deans
#
#                                              author_bio  \
# 0     Founder @WeSabio - #LearnToCode - I Blog @ htt...
# 1     Washington, D.C.-based web developer. Former c...
# 2                                                   NaN
# 3     A student at Maker’s, aspiring full stack deve...
# 4     Web Dev | Software Engineer | Creative Strateg...
# 5                                                   NaN
# 6     I love riding and training horses, hiking, coo...
# 7                          Excited @TheIronYard Student
# 8                                                   NaN
# 9     Curious about everything. Literature, Fiction,...
# 10    Fullstack Web Developer interested in learning...
# 11    Coding school for creative people & entreprene...
# 12    Washington, D.C.-based web developer. Former c...
# 13                                                  NaN
# 14                                                  NaN
# 15    Full Stack Developer | Aspiring Data Scientist...
# 16       Web dev and video game enthusiast | rhyspec.me
# 17    Ex-NHS Accountant, now a coder at Makers. July...
# 18    Full-Stack Developer // Lifelong Learner // En...
# 19                                                  NaN
# 20                                                  NaN
# 1031  Introduction and a little about accessing IEX’...  2018-05-30 11:17:13
# 1032  Learning Journal — Day 2 – Charles Clemens – M...  2018-09-12 23:51:06
# 1033             Day 37 — Meowpurrdy – conshus – Medium  2017-05-02 12:09:22
# 1034   I forgot my Password – Lauren Greenberg – Medium  2017-08-01 11:26:24
# 1035   Thinking through Problems – Emily Deans – Medium  2017-07-11 01:08:12
#
#               publisher                                               text  \
# 0               wesabio  Linked In Outcomes Report of Coding Bootcamps ...
# 1                medium  Middleware/ End of Week The last few days we’v...
# 2                medium  Week 6 — working in groups ( Airbnb clone) The...
# 3                medium  Hunting for a first job as a developer Passing...
# 4                medium  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine I ...
# 5                medium  This is a homework assignment you see. As a po...
# 6                medium  Starting at Fullstack Academy My Path to Codin...
# 7                medium  The Beginning — Journey to becoming a junior d...
# 8                medium  Coding akin to drinking from a firehose? Over ...
# 9                medium  They encouraged us to start a journal or blog ...
# 10               medium  Good Coding Habits Photo by Markus Spiske on U...
# 11               medium  On joining Startup Weekend Tokyo Fintech (and ...
# 12               medium  A P I| I P A Despite a good night’s sleep and ...
# 13               medium  The Iron Yard: Week 1 I’m just going to get st...
# 14               medium  Learn Factory Internship: Day 16 ( May 21, 201...
# 15               medium  Learning How to Learn I recently finished the ...
# 16               medium  Focusing On The End Goal Bootcamp is tough. Ve...
# 17               medium  A promise to compromise Today I discovered tha...
# 18               medium  Getting past the crux in climbing and in codin...
# 19               medium  Day 16 — Calling all A P I and S U M M E R S L...
# 20               medium  Learn Java Script in One Day Let’s be real. Co...
# 21               medium  42 Piscine Day 18 — (13) Edit: This is part of...
# 22               medium  ( Insert weird analogy here) for Git Where I c...
# 23               medium  Keeping Perspective in an Immersive Coding Boo...
# 24               medium  Ruby Newbie: Each vs. Reduce Methods The learn...
# 25               medium  5 Things to know Before Starting A Coding Boot...
# 26               medium  4 Reasons to Learn to Code You Probably Didn’t...
# 27               medium  13 Reasons Why You Should Learn to Code Learni...
# 28               medium  A New Beginning, Part 5 M E? P R O G R A M A C...
# 29               medium  A place with a difference Hello I’m Yonko . A ...
# ...                 ...                                                ...
# 1006             medium  Courses: Stanford C S193 X Web Dev Course Syll...
# 1007             medium  Five Tips to Get into Rithm It’s no secret tha...
# 1008             medium  How important is your smartphone in your life?...
# 1009             medium  Deciding Between a Bachelor’s Degree and Codin...
# 1010             medium  Don’t Believe The Hype: Coding Boot Camps Are ...
# 1011             medium  Good Code Karma When I was a kid I believed in...
# 1012             medium  How we got an app on the Play Store Armed with...
# 1013  code.likeagirl.io  Hello Nerd World! I’ve always been interested ...
# 1014            wesabio  Navy Vet Scores Tech Job and Launches App With...
# 1015             medium  Are Online Coding Bootcamps Still Important in...
# 1016             medium  Fitness Guru to Coding Neophyte: Pt 2 I’ve hea...
# 1017          codeburst  7 Things I learned in my journey from coding b...
# 1018             medium  Alumni Spotlight: Dylan Shelters’ Journey from...
# 1019             medium  How to boost your life in the biggest Lat Am s...
# 1020            wesabio  Open Letter to The Honorable Xavier Becerra At...
# 1021             medium  Extracting hash values from user input Just th...
# 1022            wesabio  Giovany Was Planning on a Career in Medicine U...
# 1023            wesabio  Tassia scores dream job at Med Men as Software...
# 1024             medium  Alpha Camp: Week 1 of 12 Learning Journal A ne...
# 1025             medium  Day 58 — This is it!liner notes: Yesterday, mo...
# 1026             medium  Getting a job as a junior developer: Tips from...
# 1027             medium  Two years ago I began tinkering with the idea ...
# 1028             medium  Something to Tell You It’s the Sunday afternoo...
# 1029             medium  Summary of Code School’s “ Try j Query” J L’s ...
# 1030             medium  Is the end nigh for Coding Bootcamps? In the l...
# 1031             medium  Introduction and a little about accessing I E ...
# 1032             medium  Learning Journal — Day 2 Code Fellows Prompt“[...
# 1033             medium  Day 37 — Meowpurrdyliner notes: So yesterday, ...
# 1034             medium  I forgot my Password This happens to me with r...
# 1035             medium  Thinking through Problems So I know the other ...
#
#                                                    tags  \
# 0                  [Learning To Code, Coding Bootcamps]
# 1     [JavaScript, Lesbians Who Tech, Women Who Code...
# 2     [Agile, Codingbootcamp, Coding, Teamwork, Java...
# 3     [Job Hunting, Developer, Makersacademy, Coding...
# 4         [Web Development, JavaScript, Codingbootcamp]
# 5     [Life, Codingbootcamp, Friends, Journey, Learn...
# 6       [Programming, Learning To Code, Codingbootcamp]
# 7     [Web Development, First Post, Codingbootcamp, ...
# 8                     [Web Development, Codingbootcamp]
# 9                     [Web Development, Codingbootcamp]
# 10    [Programming, Good Coding Practice, Codingboot...
# 11    [Startup Weekend, Fintech, Codingbootcamp, Tok...
# 12    [Web Development, Codingbootcamp, The Iron Yar...
# 13    [Coding, Web Development, Coding Bootcamps, Le...
# 14    [Internships, Coding, Codingbootcamp, JavaScript]
# 15    [Productivity, Codingbootcamp, Codelikeagirl, ...
# 16    [Life Lessons, Personal Development, Codingboo...
# 17                   [Teamwork, Makers, Codingbootcamp]
# 18    [Programming, Climbing, Codingbootcamp, Boulde...
# 19                         [JavaScript, Codingbootcamp]
# 20    [JavaScript, Coding, Codingbootcamp, Freecodec...
# 21    [Life Lessons, Ecole 42, Education, Codingboot...
# 22    [Git, The Iron Yard, Learning To Code, Web Dev...
# 23    [Web Development, Ruby, Flatiron School, Codin...
# 24    [Programming, Ruby Code, Each Method, Reduce M...
# 25    [Programming, Bootcamp, Codingbootcamp, Coding...
# 26    [Programming, Coding, Code, Learning To Code, ...
# 27    [Coding, Programming, Codingbootcamp, Web Deve...
# 28    [Web Design, Careers 19k, Codingbootcamp, Agin...
# 29    [Education, Teaching, Technology, Coding Bootc...
# ...                                                 ...
# 1006  [Programming, Coding, Codingbootcamp, Code, Ed...
# 1007  [Education, Coding, Codingbootcamp, JavaScript...
# 1008  [Mobile, Apps, Codingbootcamp, Web Development...
# 1009   [Programming, Codingbootcamp, Coding, Education]
# 1010  [Codingbootcamp, Education Technology, Innovat...
# 1011  [Programming, Coding, Codingbootcamp, Collabor...
# 27    https://medium.com/@KeepCoding_/13-reasons-why...      1
# 28    https://medium.com/@kalen7/a-surprising-career...      0
# 29    https://medium.com/@yonkokilasi/a-place-with-a...      0
# ...                                                 ...    ...
# 1006  https://medium.com/@TexasCode/courses-76337619...      1
# 1007  https://medium.com/@rithmschool/five-tips-to-g...      1
# 1008  https://medium.com/@KeepCoding_/how-important-...      0
# 1009  https://medium.com/angelhack/deciding-between-...      9
# 1010  https://medium.com/newsonthebloc/dont-believe-...      5
# 1011  https://medium.com/@verityhonebon/good-code-ka...      0
# 1012  https://medium.com/codeclan/ewa-jaime-and-mart...      0
# 1013  https://code.likeagirl.io/what-is-code-a1fd2b3...      3
# 1014  https://blog.sabio.la/navy-vet-scores-tech-job...      0
# 1015  https://medium.com/@hackreactor/are-online-cod...      0
# 1016  https://medium.com/@anthonyjarina/fitness-guru...      1
# 1017  https://codeburst.io/7-things-i-learned-in-my-...      5
# 1018  https://medium.com/@hackreactor/alumni-spotlig...      4
# 1019  https://medium.com/ironhack/how-to-boost-your-...      6
# 1020  https://blog.sabio.la/open-letter-to-the-honor...     10
# 1021  https://medium.com/@calebharnell/extracting-ha...      0
# 1022  https://blog.sabio.la/giovany-was-planning-on-...      4
# 1023  https://blog.sabio.la/tassia-scores-dream-job-...      3
# 1024  https://medium.com/@kennethteh90/alpha-camp-we...      2
# 1025  https://medium.com/@conshus/day-58-this-is-it-...      0
# 1026  https://medium.com/@ablackshear7820/getting-a-...      3
# 1027  https://medium.com/@nabilyafai90/taking-the-pl...      5
# 1028  https://medium.com/@emilyldeans/something-to-t...      1
# 1029  https://medium.com/@j_lim_j/summary-of-codesch...      0
# 1030  https://medium.com/human-learning/is-the-end-n...      1
# 1031  https://medium.com/coding-overload/introductio...      0
# 1032  https://medium.com/@cclemensjr/learning-journa...      4
# 1033  https://medium.com/@conshus/day-37-meowpurrdy-...      0
# 1034  https://medium.com/@lgreenberg23/i-forgot-my-p...      0
# 1035  https://medium.com/@emilyldeans/thinking-throu...      0
#
# [1036 rows x 9 columns]

# %%
#see frequency of different tags
Codingbootcamp_info["tags"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-733cc1f1234f> in <module>()
#       1 #see frequency of different tags
# ----> 2 Codingbootcamp_info["tags"].value_counts()
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/pandas/core/base.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#     928         from pandas.core.algorithms import value_counts
#     929         result = value_counts(self, sort=sort, ascending=ascending,
# --> 930                               normalize=normalize, bins=bins, dropna=dropna)
#     931         return result
#     932
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/pandas/core/algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     633
#     634         else:
# --> 635             keys, counts = _value_counts_arraylike(values, dropna)
#     636
#     637             if not isinstance(keys, Index):
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/pandas/core/algorithms.py in _value_counts_arraylike(values, dropna)
#     678         # TODO: handle uint8
#     679         f = getattr(htable, "value_count_{dtype}".format(dtype=ndtype))
# --> 680         keys, counts = f(values, dropna)
#     681
#     682         mask = isnull(values)
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object (pandas/_libs/hashtable.c:28955)()
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object (pandas/_libs/hashtable.c:28704)()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# We cannot get the value_counts of a list object so we need to get a little creative in order to get the value_counts of the elements in the list (tag column).

# %%
newdf = Codingbootcamp_info["tags"].apply(pd.Series).stack().reset_index(level=1, drop=True).to_frame('tags')
newdf["tags"].value_counts()
# Out:
# Codingbootcamp             967
# Coding                     467
# Programming                407
# Web Development            205
# JavaScript                 176
# Learning To Code            99
# Education                   86
# Women In Tech               71
# Software Development        59
# Tech                        49
# Ruby                        48
# Technology                  46
# The Iron Yard               41
# Coding Bootcamps            41
# Internships                 34
# Ruby on Rails               33
# Career Change               33
# Startup                     32
# Bootcamp                    32
# Learn To Code               30
# Freecodecamp                30
# Code Newbie                 28
# Ecole 42                    28
# Coding Bootcamp             28
# Code                        26
# React                       26
# Chingu                      24
# Life Lessons                24
# Women Who Code              22
# Computer Science            21
#                           ...
# Netherlands                  1
# GraphQL                      1
# Api Development              1
# Learn Programming            1
# Techadvance                  1
# Jquery                       1
# Sequelize                    1
# Soft Skills Training         1
# Learn To                     1
# Code Of Conduct              1
# Impact Hub                   1
# Xml                          1
# Trending In Higher Ed        1
# What To Do                   1
# Standards                    1
# Closing                      1
# Orangecounty                 1
# Android App Development      1
# Digital Marketing            1
# Rspectacle                   1
# Responsive Design            1
# Gojek                        1
# Sci Fi Tech                  1
# Student Loans                1
# Venture Capital              1
# Apple                        1
# Data Structures              1
# Free Student Housing         1
# Twitter                      1
# Connection                   1
# Name: tags, Length: 684, dtype: int64

# %% [markdown]
# I will play around with this more later, but for now let's look at gender of the names! We need more data than just the author name, in order to tell if they are male or female, so I am going to import the babynames data from the SSN website which may have information that is useful.

# %%
import urllib.request
import os.path
w
data_url = "https://www.ssa.gov/oact/babynames/names.zip"
local_filename = "babynames.zip"
if not os.path.exists(local_filename): # if the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

# %% [markdown]
# The data is organized into separate files in the format `yobYYYY.txt` with each file containing the `name`, `sex`, and `count` of babies registered in that year. Now we load the data directly into Python without unzipping in order to increase efficiency.

# %%
import zipfile
babynames = [] 
with zipfile.ZipFile(local_filename, "r") as zf:
    data_files = [f for f in zf.filelist if f.filename[-3:] == "txt"]
    def extract_year_from_filename(fn):
        return int(fn[3:7])
    for f in data_files:
        year = extract_year_from_filename(f.filename)
        with zf.open(f) as fp:
            df = pd.read_csv(fp, names=["Name", "Sex", "Count"])
            df["Year"] = year
            babynames.append(df)
babynames = pd.concat(babynames)

# %%
babynames.head()
# Out:
#         Name Sex  Count  Year
# 0       Mary   F   7065  1880
# 1       Anna   F   2604  1880
# 2       Emma   F   2003  1880
# 3  Elizabeth   F   1939  1880
# 4     Minnie   F   1746  1880

# %% [markdown]
# Yay now we have a babynames dataset to use!

# %% [markdown]
# Let's start off my making the names in the babynames dataset and our own data frame, lowercase (for standardization purposes so we can easily find patterns and matches). I'll create a new column for the lowercase name so we don't lose the original data.

# %%
babynames["LName"] = babynames["Name"].str.lower()
babynames.head()
# Out:
#         Name Sex  Count  Year      LName
# 0       Mary   F   7065  1880       mary
# 1       Anna   F   2604  1880       anna
# 2       Emma   F   2003  1880       emma
# 3  Elizabeth   F   1939  1880  elizabeth
# 4     Minnie   F   1746  1880     minnie

# %%
Codingbootcamp_info["lowercase author"] = Codingbootcamp_info["author"].str.lower()
Codingbootcamp_info.head()
# Out:
#             author                                         author_bio  \
# 0   Gregorio Rojas  Founder @WeSabio - #LearnToCode - I Blog @ htt...
# 1      Emily Deans  Washington, D.C.-based web developer. Former c...
# 2   Verity Honebon                                                NaN
# 3       Emily Chai  A student at Maker’s, aspiring full stack deve...
# 4  Jackson McGehee  Web Dev | Software Engineer | Creative Strateg...
#
#                                                title                 date  \
# 0  LinkedIn Outcomes Report of Coding Bootcamps –...  2016-06-01 22:46:01
# 1      Middleware/End of Week – Emily Deans – Medium  2017-07-28 20:01:22
# 2  Week 6 — working in groups (Airbnb clone) – Ve...  2017-07-31 10:57:36
# 3  Hunting for a first job as a developer – Emily...  2017-05-13 10:44:31
# 4  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine – ...  2018-02-02 17:30:29
#
#   publisher                                               text  \
# 0   wesabio  Linked In Outcomes Report of Coding Bootcamps ...
# 1    medium  Middleware/ End of Week The last few days we’v...
# 2    medium  Week 6 — working in groups ( Airbnb clone) The...
# 3    medium  Hunting for a first job as a developer Passing...
# 4    medium  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine I ...
#
#                                                 tags  \
# 0           ['Learning To Code', 'Coding Bootcamps']
# 1  ['JavaScript', 'Lesbians Who Tech', 'Women Who...
# 2  ['Agile', 'Codingbootcamp', 'Coding', 'Teamwor...
# 3  ['Job Hunting', 'Developer', 'Makersacademy', ...
# 4  ['Web Development', 'JavaScript', 'Codingbootc...
#
#                                                  url  score lowercase author
# 0  https://researchcodingbootcamps.com/linkedin-o...     10   gregorio rojas
# 1  https://medium.com/@emilyldeans/middleware-end...      0      emily deans
# 2  https://medium.com/@verityhonebon/week-6-worki...      1   verity honebon
# 3  https://medium.com/@emilyxchai/hunting-for-a-f...      0       emily chai
# 4  https://medium.com/@jacksonfullstack/notes-fro...      0  jackson mcgehee

# %% [markdown]
# See the total number of babies with each name broken down by sex.

# %%
sex_counts = pd.pivot_table(babynames, index='LName', columns='Sex', values='Count',
                            aggfunc='sum', fill_value=0., margins=True)
sex_counts.head()
# Out:
# Sex           F      M    All
# LName
# aaban       0.0  107.0  107.0
# aabha      35.0    0.0   35.0
# aabid       0.0   10.0   10.0
# aabir       0.0    5.0    5.0
# aabriella  32.0    0.0   32.0

# %% [markdown]
# Calculate the probability a name is female:

# %%
prob_female = sex_counts['F'] / sex_counts['All'] 
prob_female.head(10)
# Out:
# LName
# aaban        0.000000
# aabha        1.000000
# aabid        0.000000
# aabir        0.000000
# aabriella    1.000000
# aada         1.000000
# aadam        0.000000
# aadan        0.000000
# aadarsh      0.000000
# aaden        0.001073
# dtype: float64

# %%
prob_female["shalini"]
# Out:
# 1.0

# %% [markdown]
# Similarly, we can calculate the probability a name is male:

# %%
prob_male = sex_counts['M'] / sex_counts['All'] 
prob_male.head(10)
# Out:
# LName
# aaban        1.000000
# aabha        0.000000
# aabid        1.000000
# aabir        1.000000
# aabriella    0.000000
# aada         0.000000
# aadam        1.000000
# aadan        1.000000
# aadarsh      1.000000
# aaden        0.998927
# dtype: float64

# %% [markdown]
# I will define a function to return the most likely `Sex` for a name. If there is an exact tie, the function returns Male. If the name does not appear in the social security dataset, return Unknown.

# %%
def sex_from_name(name):
    lower_name = name.lower()
    if lower_name in prob_female.index:
        return 'F' if prob_female[lower_name] > 0.5 else 'M'
    else:
        return "Unknown"

def prob_female_from_name(name):
    lower_name = name.lower()
    if lower_name in prob_female.index:
        return prob_female[lower_name] 
    else:
        return "Unknown"
    
def prob_male_from_name(name):
    lower_name = name.lower()
    if lower_name in prob_male.index:
        return prob_male[lower_name] 
    else:
        return "Unknown"

# %%
shalini_sex = sex_from_name('shalini')
shalini_sex
# Out:
# 'F'

# %%
sex_from_name('aaden')
# Out:
# 'M'

# %%
prob_female_from_name('shalini')
# Out:
# 1.0

# %% [markdown]
# Now let me find a way to apply this function to our own dataframe in order to predict the gender of the different authors.
# Next steps:
# * Need to get the first name of the author
# * Filter out any companies/orgs that may be in the author column
# * Apply sex_from_name function to names in the bootcamp dataframe
# * Have a confidence interval (if possible) or different measure of how sure we are about the given gender
# * Create different dataframes with org data and personal data (as publisher/author)

# %% [markdown]
# Let's go back to our dataframe and filter out anything that may be companies or organizations

# %%
Codingbootcamp_info.head()
# Out:
#             author                                         author_bio  \
# 0   Gregorio Rojas  Founder @WeSabio - #LearnToCode - I Blog @ htt...
# 1      Emily Deans  Washington, D.C.-based web developer. Former c...
# 2   Verity Honebon                                                NaN
# 3       Emily Chai  A student at Maker’s, aspiring full stack deve...
# 4  Jackson McGehee  Web Dev | Software Engineer | Creative Strateg...
#
#                                                title                 date  \
# 0  LinkedIn Outcomes Report of Coding Bootcamps –...  2016-06-01 22:46:01
# 1      Middleware/End of Week – Emily Deans – Medium  2017-07-28 20:01:22
# 2  Week 6 — working in groups (Airbnb clone) – Ve...  2017-07-31 10:57:36
# 3  Hunting for a first job as a developer – Emily...  2017-05-13 10:44:31
# 4  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine – ...  2018-02-02 17:30:29
#
#   publisher                                               text  \
# 0   wesabio  Linked In Outcomes Report of Coding Bootcamps ...
# 1    medium  Middleware/ End of Week The last few days we’v...
# 2    medium  Week 6 — working in groups ( Airbnb clone) The...
# 3    medium  Hunting for a first job as a developer Passing...
# 4    medium  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine I ...
#
#                                                 tags  \
# 0           ['Learning To Code', 'Coding Bootcamps']
# 1  ['JavaScript', 'Lesbians Who Tech', 'Women Who...
# 2  ['Agile', 'Codingbootcamp', 'Coding', 'Teamwor...
# 3  ['Job Hunting', 'Developer', 'Makersacademy', ...
# 4  ['Web Development', 'JavaScript', 'Codingbootc...
#
#                                                  url  score lowercase author
# 0  https://researchcodingbootcamps.com/linkedin-o...     10   gregorio rojas
# 1  https://medium.com/@emilyldeans/middleware-end...      0      emily deans
# 2  https://medium.com/@verityhonebon/week-6-worki...      1   verity honebon
# 3  https://medium.com/@emilyxchai/hunting-for-a-f...      0       emily chai
# 4  https://medium.com/@jacksonfullstack/notes-fro...      0  jackson mcgehee

# %% [markdown]
# A list of the things to filter out: when publisher is wesabio, code.likeagirl.io, makersacademy, hackernoon, fuerzamuktek, codeburst, ubiqum, fundapps, itnext.io, propulsioncodingacademy, PrototyprIO.

# %%
orgs = ["wesabio", "code.likeagirl.io", "makersacademy", "hackernoon", "fuerzamuktek", "codeburst", "ubiqum", "fundapps", "itnext.io", "propulsioncodingacademy", "PrototyprIO"]
new_codingdf = Codingbootcamp_info[~Codingbootcamp_info["publisher"].isin(orgs)]
orgs_df = Codingbootcamp_info[Codingbootcamp_info["publisher"].isin(orgs)]
new_codingdf
# Out:
#                         author  \
# 1                  Emily Deans
# 2               Verity Honebon
# 3                   Emily Chai
# 4              Jackson McGehee
# 5                 Bree Jackson
# 6                Sara Jo Helba
# 7                Emmanuel Amon
# 8                    sam foong
# 9              Joseph Cardillo
# 10                    Joe Andy
# 11              Le Wagon Tokyo
# 12                 Emily Deans
# 13                 Gabe Wright
# 14            chibueze ukaegbu
# 15                Zaynaib Giwa
# 16              Rhys Woodberry
# 17                Angela Wolff
# 18              Monica Kosciuk
# 19                 Jacob Moore
# 20              Taylor Edwards
# 21                  Mike Brave
# 22               it’s jennilyn
# 23             Brigit Rossbach
# 24               Timika Downes
# 25              Sam Pellegrene
# 26                Hack Reactor
# 27                  KeepCoding
# 28               Kalen Hammann
# 29                Yonko Kilasi
# 30            Kamrin Klauschie
# ...                        ...
# 1000              Leibel Hecht
# 1001          Jonathan Jackson
# 1002          Berkan Asanovski
# 1003                  Max Lowe
# 1004  Francesco Pio Squillante
# 1005              Matt McMahon
# 1006           Code Collective
# 1007              Rithm School
# 1008                KeepCoding
# 1009                 AngelHack
# 1010             Clint Schmidt
# 1011            Verity Honebon
# 1012                  CodeClan
# 1015              Hack Reactor
# 1016            Anthony Jarina
# 1018              Hack Reactor
# 1019             Mario Posadas
# 1021             Caleb Harnell
# 1024               Kenneth Teh
# 1025                   conshus
# 1026          Aaron Blackshear
# 1027               Nabil Yafai
# 1028               Emily Deans
# 1029                     J.Lim
# 1030          Chris Fellingham
# 1031     Nicholas Vincent-Hill
# 1032           Charles Clemens
# 1033                   conshus
# 1034          Lauren Greenberg
# 1035               Emily Deans
#
#                                              author_bio  \
# 1     Washington, D.C.-based web developer. Former c...
# 2                                                   NaN
# 3     A student at Maker’s, aspiring full stack deve...
# 4     Web Dev | Software Engineer | Creative Strateg...
# 5                                                   NaN
# 6     I love riding and training horses, hiking, coo...
# 7                          Excited @TheIronYard Student
# 8                                                   NaN
# 9     Curious about everything. Literature, Fiction,...
# 10    Fullstack Web Developer interested in learning...
# 11    Coding school for creative people & entreprene...
# 12    Washington, D.C.-based web developer. Former c...
# 13                                                  NaN
# 14                                                  NaN
# 15    Full Stack Developer | Aspiring Data Scientist...
# 16       Web dev and video game enthusiast | rhyspec.me
# 17    Ex-NHS Accountant, now a coder at Makers. July...
# 18    Full-Stack Developer // Lifelong Learner // En...
# 19                                                  NaN
# 20                                                  NaN
# 21    I make things with design and code. Here's to ...
# 22    Proud to be a #WomanInTech. Software developer...
# 23          Software Engineer in Missoula, MT. Yale '16
# 24    Mom of three, lover of learning, intermittent ...
# 25             UX Developer. I blog about random stuff.
# 26    Providing the 21st century CS degree. We turn ...
# 27    We create the best learning experience for Ful...
# 28                                                  NaN
# 29                                                  NaN
# 30          Be the hustle you wish to see in the world.
# ...                                                 ...
# 1000  I’m Leibel. I’m transitioning from Talmud to T...
# 1001  Facilitator at W3develops. Apply here: w3devel...
# 1002                                 Sometimes i write…
# 1003                                                NaN
# 1004                Just a guy who loves coding outside
# 1005  Full Stack Web Developer, Skeptic, and Unapolo...
# 1006  Exposing the world to code. Questions/Feedback...
# 1007  18 week program on #JavaScript #ReactJS and #P...
# 1008  We create the best learning experience for Ful...
# 1009  AngelHack ignites the passion of the world's m...
# 1010      Former CEO at Bloc. I build growth companies.
# 1011                                                NaN
# 1012  16-week intensive and part-time software devel...
# 1015  Providing the 21st century CS degree. We turn ...
# 1016                                                NaN
# 1018  Providing the 21st century CS degree. We turn ...
# 1019                            Ironhack Expansion Lead
# 1021  Coder Academy Fast-track student — https://www...
# 1024                                                NaN
# 1025  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1026  Full-Stack Javascript Developer in Dallas, Tex...
# 1027  Full stack developer trying to not become obso...
# 1028  Washington, D.C.-based web developer. Former c...
# 1029  Learning JavaScript, Vue.js, Sass, Python, Dja...
# 1030  I’m Chris, I formerly worked in Strategy for F...
# 1031  Trader and Programmer http://www.nickvh.fun/ h...
# 1032                                                NaN
# 1033  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1034  Exploring programming, my assumptions and the ...
# 1035  Washington, D.C.-based web developer. Former c...
#
#                                                   title                 date  \
# 1         Middleware/End of Week – Emily Deans – Medium  2017-07-28 20:01:22
# 2     Week 6 — working in groups (Airbnb clone) – Ve...  2017-07-31 10:57:36
# 3     Hunting for a first job as a developer – Emily...  2017-05-13 10:44:31
# 4     Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine – ...  2018-02-02 17:30:29
# 5     This is a homework assignment you see. – Bree ...  2017-08-11 03:11:39
# 6     Starting at Fullstack Academy – Sara Jo Helba ...  2017-07-21 19:13:17
# 7     The Beginning — Journey to becoming a junior d...  2017-07-15 18:23:18
# 1018  Alumni Spotlight: Dylan Shelters’ Journey from...  2018-08-14 13:01:01
# 1019  How to boost your life in the biggest LatAm st...  2018-05-22 12:08:34
# 1021  Extracting hash values from user input – Caleb...  2017-08-03 09:24:13
# 1024  Alpha Camp: Week 1 of 12 Learning Journal – Ke...  2017-10-01 16:18:34
# 1025            Day 58 — This is it! – conshus – Medium  2017-06-01 10:51:53
# 1026  Getting a job as a junior developer: Tips from...  2018-08-11 19:21:58
# 1027  Taking The Plunge to Become a Software Enginee...  2018-05-13 17:33:25
# 1028       Something to Tell You – Emily Deans – Medium  2017-07-16 21:08:04
# 1029  Summary of CodeSchool's "Try jQuery" – J.Lim –...  2018-05-24 15:56:25
# 1030  Is the end nigh for Coding Bootcamps? – Human ...  2017-08-09 12:11:17
# 1031  Introduction and a little about accessing IEX’...  2018-05-30 11:17:13
# 1032  Learning Journal — Day 2 – Charles Clemens – M...  2018-09-12 23:51:06
# 1033             Day 37 — Meowpurrdy – conshus – Medium  2017-05-02 12:09:22
# 1034   I forgot my Password – Lauren Greenberg – Medium  2017-08-01 11:26:24
# 1035   Thinking through Problems – Emily Deans – Medium  2017-07-11 01:08:12
#
#      publisher                                               text  \
# 1       medium  Middleware/ End of Week The last few days we’v...
# 2       medium  Week 6 — working in groups ( Airbnb clone) The...
# 3       medium  Hunting for a first job as a developer Passing...
# 4       medium  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine I ...
# 5       medium  This is a homework assignment you see. As a po...
# 6       medium  Starting at Fullstack Academy My Path to Codin...
# 7       medium  The Beginning — Journey to becoming a junior d...
# 8       medium  Coding akin to drinking from a firehose? Over ...
# 9       medium  They encouraged us to start a journal or blog ...
# 10      medium  Good Coding Habits Photo by Markus Spiske on U...
# 11      medium  On joining Startup Weekend Tokyo Fintech (and ...
# 12      medium  A P I| I P A Despite a good night’s sleep and ...
# 13      medium  The Iron Yard: Week 1 I’m just going to get st...
# 14      medium  Learn Factory Internship: Day 16 ( May 21, 201...
# 15      medium  Learning How to Learn I recently finished the ...
# 16      medium  Focusing On The End Goal Bootcamp is tough. Ve...
# 17      medium  A promise to compromise Today I discovered tha...
# 18      medium  Getting past the crux in climbing and in codin...
# 19      medium  Day 16 — Calling all A P I and S U M M E R S L...
# 20      medium  Learn Java Script in One Day Let’s be real. Co...
# 21      medium  42 Piscine Day 18 — (13) Edit: This is part of...
# 22      medium  ( Insert weird analogy here) for Git Where I c...
# 23      medium  Keeping Perspective in an Immersive Coding Boo...
# 24      medium  Ruby Newbie: Each vs. Reduce Methods The learn...
# 25      medium  5 Things to know Before Starting A Coding Boot...
# 26      medium  4 Reasons to Learn to Code You Probably Didn’t...
# 27      medium  13 Reasons Why You Should Learn to Code Learni...
# 28      medium  A New Beginning, Part 5 M E? P R O G R A M A C...
# 29      medium  A place with a difference Hello I’m Yonko . A ...
# 30      medium  How To Choose a Bootcamp Like a Bootcamp Emplo...
# ...        ...                                                ...
# 1000    medium  Portfolio is live! Plus apps are mobile friend...
# 1001    medium  Chapter 5 — Finished projects & What have peop...
# 1002    medium  Why you should pay for a Coding Boot camp, or ...
# 1003    medium  Imposter Syndrome and The Shawshank Redemption...
# 1004    medium  How should you learn coding? Versione italiana...
# 1005    medium  Great introduction to the typical for-loop, bu...
# 1006    medium  Courses: Stanford C S193 X Web Dev Course Syll...
# 1007    medium  Five Tips to Get into Rithm It’s no secret tha...
# 1008    medium  How important is your smartphone in your life?...
# 1009    medium  Deciding Between a Bachelor’s Degree and Codin...
# 1010    medium  Don’t Believe The Hype: Coding Boot Camps Are ...
# 1011    medium  Good Code Karma When I was a kid I believed in...
# 1012    medium  How we got an app on the Play Store Armed with...
# 1015    medium  Are Online Coding Bootcamps Still Important in...
# 1016    medium  Fitness Guru to Coding Neophyte: Pt 2 I’ve hea...
# 1018    medium  Alumni Spotlight: Dylan Shelters’ Journey from...
# 1019    medium  How to boost your life in the biggest Lat Am s...
# 1021    medium  Extracting hash values from user input Just th...
# 1024    medium  Alpha Camp: Week 1 of 12 Learning Journal A ne...
# 1025    medium  Day 58 — This is it!liner notes: Yesterday, mo...
# 1026    medium  Getting a job as a junior developer: Tips from...
# 1027    medium  Two years ago I began tinkering with the idea ...
# 1028    medium  Something to Tell You It’s the Sunday afternoo...
# 1029    medium  Summary of Code School’s “ Try j Query” J L’s ...
# 1030    medium  Is the end nigh for Coding Bootcamps? In the l...
# 1031    medium  Introduction and a little about accessing I E ...
# 1032    medium  Learning Journal — Day 2 Code Fellows Prompt“[...
# 1033    medium  Day 37 — Meowpurrdyliner notes: So yesterday, ...
# 1034    medium  I forgot my Password This happens to me with r...
# 1035    medium  Thinking through Problems So I know the other ...
#
#                                                    tags  \
# 1     ['JavaScript', 'Lesbians Who Tech', 'Women Who...
# 2     ['Agile', 'Codingbootcamp', 'Coding', 'Teamwor...
# 3     ['Job Hunting', 'Developer', 'Makersacademy', ...
# 4     ['Web Development', 'JavaScript', 'Codingbootc...
# 5     ['Life', 'Codingbootcamp', 'Friends', 'Journey...
# 6     ['Programming', 'Learning To Code', 'Codingboo...
# 7     ['Web Development', 'First Post', 'Codingbootc...
# 8                 ['Web Development', 'Codingbootcamp']
# 9                 ['Web Development', 'Codingbootcamp']
# 10    ['Programming', 'Good Coding Practice', 'Codin...
# 11    ['Startup Weekend', 'Fintech', 'Codingbootcamp...
# 12    ['Web Development', 'Codingbootcamp', 'The Iro...
# 13    ['Coding', 'Web Development', 'Coding Bootcamp...
# 14    ['Internships', 'Coding', 'Codingbootcamp', 'J...
# 15    ['Productivity', 'Codingbootcamp', 'Codelikeag...
# 16    ['Life Lessons', 'Personal Development', 'Codi...
# 17             ['Teamwork', 'Makers', 'Codingbootcamp']
# 18    ['Programming', 'Climbing', 'Codingbootcamp', ...
# 19                     ['JavaScript', 'Codingbootcamp']
# 20    ['JavaScript', 'Coding', 'Codingbootcamp', 'Fr...
# 21    ['Life Lessons', 'Ecole 42', 'Education', 'Cod...
# 22    ['Git', 'The Iron Yard', 'Learning To Code', '...
# 23    ['Web Development', 'Ruby', 'Flatiron School',...
# 24    ['Programming', 'Ruby Code', 'Each Method', 'R...
# 25    ['Programming', 'Bootcamp', 'Codingbootcamp', ...
# 26    ['Programming', 'Coding', 'Code', 'Learning To...
# 27    ['Coding', 'Programming', 'Codingbootcamp', 'W...
# 28    ['Web Design', 'Careers 19k', 'Codingbootcamp'...
# 29    ['Education', 'Teaching', 'Technology', 'Codin...
# 30    ['Programming', 'Education', 'Software', 'Codi...
# ...                                                 ...
# 1000  ['Web Development', 'Portfolio', 'Coding', 'Co...
# 1001  ['Programming', 'Pair Programming', 'Codingboo...
# 1002       ['Bootcamp', 'Codingbootcamp', 'Connection']
# 1003    ['Imposter Syndrome', 'Bloc', 'Codingbootcamp']
# 1004  ['Programming', 'Teaching', 'Methodology', 'Co...
# 1005  ['JavaScript', 'Ruby on Rails', 'Codingbootcam...
# 1006  ['Programming', 'Coding', 'Codingbootcamp', 'C...
# 1007  ['Education', 'Coding', 'Codingbootcamp', 'Jav...
# 1008  ['Mobile', 'Apps', 'Codingbootcamp', 'Web Deve...
# 1009  ['Programming', 'Codingbootcamp', 'Coding', 'E...
# 1010  ['Codingbootcamp', 'Education Technology', 'In...
# 1011  ['Programming', 'Coding', 'Codingbootcamp', 'C...
# 1012  ['Android', 'Coding', 'Codingbootcamp', 'Learn...
# 1015  ['Programming', 'Coding', 'Codingbootcamp', 'R...
# 1016  ['Entrepreneurship', 'Career Advice', 'Career ...
# 1018  ['Hack Reactor', 'React', 'Engineering', 'Prog...
# 1019  ['Startup', 'Codingbootcamp', 'Ironhack', 'Tec...
# 1021  ['Ruby', 'Coding', 'Codingbootcamp', 'Code', '...
# 1024  ['Programming', 'Alphacamp', 'Ruby', 'Codingbo...
# 1025  ['Hip Hop', 'Coding', 'Code', 'Codingbootcamp'...
# 1026  ['Programming', 'Codingbootcamp', 'Job Hunting...
# 1027  ['Programming', 'JavaScript', 'Learning To Cod...
# 1028  ['Web Development', 'Codingbootcamp', 'Women W...
# 1029  ['JavaScript', 'Jquery', 'Code School', 'Codin...
# 1030  ['Programming', 'Edtech', 'Codingbootcamp', 'C...
# 1031  ['JavaScript', 'React', 'Coding', 'Codingbootc...
# 1032  ['Coding', 'Codingbootcamp', 'Learning To Code...
# 1033  ['Firebase', 'Code', 'Coding', 'Codingbootcamp...
# 1034  ['Security', 'Ruby', 'Ruby on Rails', 'Codingb...
# 1035  ['Writing', 'Codingbootcamp', 'The Iron Yard',...
#
#                                                     url  score  \
# 1     https://medium.com/@emilyldeans/middleware-end...      0
# 2     https://medium.com/@verityhonebon/week-6-worki...      1
# 3     https://medium.com/@emilyxchai/hunting-for-a-f...      0
# 4     https://medium.com/@jacksonfullstack/notes-fro...      0
# 5     https://medium.com/@breejax/as-a-possible-futu...      0
# 6     https://medium.com/@sjhelba/starting-at-fullst...      3
# 7     https://medium.com/@emmanuelamon92/the-beginni...      4
# 1034  https://medium.com/@lgreenberg23/i-forgot-my-p...      0
# 1035  https://medium.com/@emilyldeans/thinking-throu...      0
#
#               lowercase author
# 1                  emily deans
# 2               verity honebon
# 3                   emily chai
# 4              jackson mcgehee
# 5                 bree jackson
# 6                sara jo helba
# 7                emmanuel amon
# 8                    sam foong
# 9              joseph cardillo
# 10                    joe andy
# 11              le wagon tokyo
# 12                 emily deans
# 13                 gabe wright
# 14            chibueze ukaegbu
# 15                zaynaib giwa
# 16              rhys woodberry
# 17                angela wolff
# 18              monica kosciuk
# 19                 jacob moore
# 20              taylor edwards
# 21                  mike brave
# 22               it’s jennilyn
# 23             brigit rossbach
# 24               timika downes
# 25              sam pellegrene
# 26                hack reactor
# 27                  keepcoding
# 28               kalen hammann
# 29                yonko kilasi
# 30            kamrin klauschie
# ...                        ...
# 1000              leibel hecht
# 1001          jonathan jackson
# 1002          berkan asanovski
# 1003                  max lowe
# 1004  francesco pio squillante
# 1005              matt mcmahon
# 1006           code collective
# 1007              rithm school
# 1008                keepcoding
# 1009                 angelhack
# 1010             clint schmidt
# 1011            verity honebon
# 1012                  codeclan
# 1015              hack reactor
# 1016            anthony jarina
# 1018              hack reactor
# 1019             mario posadas
# 1021             caleb harnell
# 1024               kenneth teh
# 1025                   conshus
# 1026          aaron blackshear
# 1027               nabil yafai
# 1028               emily deans
# 1029                     j.lim
# 1030          chris fellingham
# 1031     nicholas vincent-hill
# 1032           charles clemens
# 1033                   conshus
# 1034          lauren greenberg
# 1035               emily deans
#
# [954 rows x 10 columns]

# %% [markdown]
# From a manual look at the filtered dataframe, I am also going to filter out rows that have author KeepCoding, Better Developer, Manchester Codes, Code Collective, Accelerate Tech, Rithm School.

# %%
more_orgs = ["KeepCoding", "Better Developer", "Manchester Codes", "Code Collective", "Accelerate Tech", "Rithm School"]
new_codingdf = new_codingdf[~new_codingdf["author"].isin(more_orgs)]
new_codingdf
# Out:
#                         author  \
# 1                  Emily Deans
# 2               Verity Honebon
# 3                   Emily Chai
# 4              Jackson McGehee
# 5                 Bree Jackson
# 6                Sara Jo Helba
# 7                Emmanuel Amon
# 8                    sam foong
# 9              Joseph Cardillo
# 10                    Joe Andy
# 11              Le Wagon Tokyo
# 12                 Emily Deans
# 13                 Gabe Wright
# 14            chibueze ukaegbu
# 15                Zaynaib Giwa
# 16              Rhys Woodberry
# 17                Angela Wolff
# 18              Monica Kosciuk
# 19                 Jacob Moore
# 20              Taylor Edwards
# 21                  Mike Brave
# 22               it’s jennilyn
# 23             Brigit Rossbach
# 24               Timika Downes
# 25              Sam Pellegrene
# 26                Hack Reactor
# 28               Kalen Hammann
# 29                Yonko Kilasi
# 30            Kamrin Klauschie
# 31                Chung Nguyen
# ...                        ...
# 996              Drew Campbell
# 997           Ethan R. Roberts
# 998          Divyansh Tripathi
# 1000              Leibel Hecht
# 1001          Jonathan Jackson
# 1002          Berkan Asanovski
# 1003                  Max Lowe
# 1004  Francesco Pio Squillante
# 1005              Matt McMahon
# 1009                 AngelHack
# 1010             Clint Schmidt
# 1011            Verity Honebon
# 1012                  CodeClan
# 1015              Hack Reactor
# 1016            Anthony Jarina
# 1018              Hack Reactor
# 1019             Mario Posadas
# 1021             Caleb Harnell
# 1024               Kenneth Teh
# 1025                   conshus
# 1026          Aaron Blackshear
# 1027               Nabil Yafai
# 1028               Emily Deans
# 1029                     J.Lim
# 1030          Chris Fellingham
# 1031     Nicholas Vincent-Hill
# 1032           Charles Clemens
# 1033                   conshus
# 1034          Lauren Greenberg
# 1035               Emily Deans
#
#                                              author_bio  \
# 1     Washington, D.C.-based web developer. Former c...
# 2                                                   NaN
# 3     A student at Maker’s, aspiring full stack deve...
# 4     Web Dev | Software Engineer | Creative Strateg...
# 5                                                   NaN
# 6     I love riding and training horses, hiking, coo...
# 7                          Excited @TheIronYard Student
# 8                                                   NaN
# 9     Curious about everything. Literature, Fiction,...
# 10    Fullstack Web Developer interested in learning...
# 11    Coding school for creative people & entreprene...
# 12    Washington, D.C.-based web developer. Former c...
# 13                                                  NaN
# 14                                                  NaN
# 15    Full Stack Developer | Aspiring Data Scientist...
# 16       Web dev and video game enthusiast | rhyspec.me
# 17    Ex-NHS Accountant, now a coder at Makers. July...
# 18    Full-Stack Developer // Lifelong Learner // En...
# 19                                                  NaN
# 20                                                  NaN
# 21    I make things with design and code. Here's to ...
# 22    Proud to be a #WomanInTech. Software developer...
# 23          Software Engineer in Missoula, MT. Yale '16
# 24    Mom of three, lover of learning, intermittent ...
# 25             UX Developer. I blog about random stuff.
# 26    Providing the 21st century CS degree. We turn ...
# 28                                                  NaN
# 29                                                  NaN
# 30          Be the hustle you wish to see in the world.
# 31    Software engineer, portrait photographer, hand...
# ...                                                 ...
# 996   Unity Developer | Game Developer | VR | Blogge...
# 997                  Full-Stack Software Engineer | NYC
# 998                      I have no idea what i’m doing.
# 1000  I’m Leibel. I’m transitioning from Talmud to T...
# 1001  Facilitator at W3develops. Apply here: w3devel...
# 1002                                 Sometimes i write…
# 1003                                                NaN
# 1004                Just a guy who loves coding outside
# 1005  Full Stack Web Developer, Skeptic, and Unapolo...
# 1009  AngelHack ignites the passion of the world's m...
# 1010      Former CEO at Bloc. I build growth companies.
# 1011                                                NaN
# 1012  16-week intensive and part-time software devel...
# 1015  Providing the 21st century CS degree. We turn ...
# 1016                                                NaN
# 1018  Providing the 21st century CS degree. We turn ...
# 1019                            Ironhack Expansion Lead
# 1021  Coder Academy Fast-track student — https://www...
# 1024                                                NaN
# 1025  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1026  Full-Stack Javascript Developer in Dallas, Tex...
# 1027  Full stack developer trying to not become obso...
# 1028  Washington, D.C.-based web developer. Former c...
# 1029  Learning JavaScript, Vue.js, Sass, Python, Dja...
# 1030  I’m Chris, I formerly worked in Strategy for F...
# 1031  Trader and Programmer http://www.nickvh.fun/ h...
# 1032                                                NaN
# 1033  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
#
# 22      medium  ( Insert weird analogy here) for Git Where I c...
# 23      medium  Keeping Perspective in an Immersive Coding Boo...
# 24      medium  Ruby Newbie: Each vs. Reduce Methods The learn...
# 25      medium  5 Things to know Before Starting A Coding Boot...
# 26      medium  4 Reasons to Learn to Code You Probably Didn’t...
# 28      medium  A New Beginning, Part 5 M E? P R O G R A M A C...
# 29      medium  A place with a difference Hello I’m Yonko . A ...
# 30      medium  How To Choose a Bootcamp Like a Bootcamp Emplo...
# 31      medium  Managing Your Post- Bootcamp Job Search A temp...
# ...        ...                                                ...
# 996     medium  Programming Fundamentals: Algorithms Welcome t...
# 997     medium  Regexes: Our Not- So- Regular Expressions You ...
# 998     medium  My terminal is sexy and i know it. An another ...
# 1000    medium  Portfolio is live! Plus apps are mobile friend...
# 1001    medium  Chapter 5 — Finished projects & What have peop...
# 1002    medium  Why you should pay for a Coding Boot camp, or ...
# 1003    medium  Imposter Syndrome and The Shawshank Redemption...
# 1004    medium  How should you learn coding? Versione italiana...
# 1005    medium  Great introduction to the typical for-loop, bu...
# 1009    medium  Deciding Between a Bachelor’s Degree and Codin...
# 1010    medium  Don’t Believe The Hype: Coding Boot Camps Are ...
# 1011    medium  Good Code Karma When I was a kid I believed in...
# 1012    medium  How we got an app on the Play Store Armed with...
# 1015    medium  Are Online Coding Bootcamps Still Important in...
# 1016    medium  Fitness Guru to Coding Neophyte: Pt 2 I’ve hea...
# 1018    medium  Alumni Spotlight: Dylan Shelters’ Journey from...
# 1019    medium  How to boost your life in the biggest Lat Am s...
# 1021    medium  Extracting hash values from user input Just th...
# 1024    medium  Alpha Camp: Week 1 of 12 Learning Journal A ne...
# 1025    medium  Day 58 — This is it!liner notes: Yesterday, mo...
# 1026    medium  Getting a job as a junior developer: Tips from...
# 1027    medium  Two years ago I began tinkering with the idea ...
# 1028    medium  Something to Tell You It’s the Sunday afternoo...
# 1029    medium  Summary of Code School’s “ Try j Query” J L’s ...
# 1030    medium  Is the end nigh for Coding Bootcamps? In the l...
# 1031    medium  Introduction and a little about accessing I E ...
# 1032    medium  Learning Journal — Day 2 Code Fellows Prompt“[...
# 1033    medium  Day 37 — Meowpurrdyliner notes: So yesterday, ...
# 1034    medium  I forgot my Password This happens to me with r...
# 1035    medium  Thinking through Problems So I know the other ...
#
#                                                    tags  \
# 1     ['JavaScript', 'Lesbians Who Tech', 'Women Who...
# 2     ['Agile', 'Codingbootcamp', 'Coding', 'Teamwor...
# 3     ['Job Hunting', 'Developer', 'Makersacademy', ...
# 4     ['Web Development', 'JavaScript', 'Codingbootc...
# 5     ['Life', 'Codingbootcamp', 'Friends', 'Journey...
# 6     ['Programming', 'Learning To Code', 'Codingboo...
# 7     ['Web Development', 'First Post', 'Codingbootc...
# 8                 ['Web Development', 'Codingbootcamp']
# 9                 ['Web Development', 'Codingbootcamp']
# 10    ['Programming', 'Good Coding Practice', 'Codin...
# 11    ['Startup Weekend', 'Fintech', 'Codingbootcamp...
# 12    ['Web Development', 'Codingbootcamp', 'The Iro...
# 13    ['Coding', 'Web Development', 'Coding Bootcamp...
# 14    ['Internships', 'Coding', 'Codingbootcamp', 'J...
# 15    ['Productivity', 'Codingbootcamp', 'Codelikeag...
# 16    ['Life Lessons', 'Personal Development', 'Codi...
# 17             ['Teamwork', 'Makers', 'Codingbootcamp']
# 18    ['Programming', 'Climbing', 'Codingbootcamp', ...
# 19                     ['JavaScript', 'Codingbootcamp']
# 20    ['JavaScript', 'Coding', 'Codingbootcamp', 'Fr...
# 21    ['Life Lessons', 'Ecole 42', 'Education', 'Cod...
# 22    ['Git', 'The Iron Yard', 'Learning To Code', '...
# 23    ['Web Development', 'Ruby', 'Flatiron School',...
# 24    ['Programming', 'Ruby Code', 'Each Method', 'R...
# 25    ['Programming', 'Bootcamp', 'Codingbootcamp', ...
# 26    ['Programming', 'Coding', 'Code', 'Learning To...
# 28    ['Web Design', 'Careers 19k', 'Codingbootcamp'...
# 29    ['Education', 'Teaching', 'Technology', 'Codin...
# 30    ['Programming', 'Education', 'Software', 'Codi...
# 31    ['Jobs', 'Job Hunting', 'Codingbootcamp', 'Tre...
# ...                                                 ...
# 996   ['Algorithms', 'Programming', 'Coding', 'Codin...
# 997   ['Regex', 'Ruby', 'Codingbootcamp', 'Programmi...
# 998   ['Git', 'Github', 'Codingbootcamp', 'Cli', 'In...
# 1000  ['Web Development', 'Portfolio', 'Coding', 'Co...
# 1001  ['Programming', 'Pair Programming', 'Codingboo...
# 1002       ['Bootcamp', 'Codingbootcamp', 'Connection']
# 1003    ['Imposter Syndrome', 'Bloc', 'Codingbootcamp']
# 1004  ['Programming', 'Teaching', 'Methodology', 'Co...
# 1005  ['JavaScript', 'Ruby on Rails', 'Codingbootcam...
# 1009  ['Programming', 'Codingbootcamp', 'Coding', 'E...
# 1010  ['Codingbootcamp', 'Education Technology', 'In...
# 1011  ['Programming', 'Coding', 'Codingbootcamp', 'C...
# 1012  ['Android', 'Coding', 'Codingbootcamp', 'Learn...
# 1015  ['Programming', 'Coding', 'Codingbootcamp', 'R...
# 1016  ['Entrepreneurship', 'Career Advice', 'Career ...
# 1018  ['Hack Reactor', 'React', 'Engineering', 'Prog...
# 1019  ['Startup', 'Codingbootcamp', 'Ironhack', 'Tec...
# 1021  ['Ruby', 'Coding', 'Codingbootcamp', 'Code', '...
# 1024  ['Programming', 'Alphacamp', 'Ruby', 'Codingbo...
# 1025  ['Hip Hop', 'Coding', 'Code', 'Codingbootcamp'...
# 1026  ['Programming', 'Codingbootcamp', 'Job Hunting...
# 1027  ['Programming', 'JavaScript', 'Learning To Cod...
# 1028  ['Web Development', 'Codingbootcamp', 'Women W...
# 1029  ['JavaScript', 'Jquery', 'Code School', 'Codin...
# 1030  ['Programming', 'Edtech', 'Codingbootcamp', 'C...
# 1031  ['JavaScript', 'React', 'Coding', 'Codingbootc...
# 1032  ['Coding', 'Codingbootcamp', 'Learning To Code...
# 1033  ['Firebase', 'Code', 'Coding', 'Codingbootcamp...
# 1034  ['Security', 'Ruby', 'Ruby on Rails', 'Codingb...
# 1025  https://medium.com/@conshus/day-58-this-is-it-...      0
# 1026  https://medium.com/@ablackshear7820/getting-a-...      3
# 1027  https://medium.com/@nabilyafai90/taking-the-pl...      5
# 1028  https://medium.com/@emilyldeans/something-to-t...      1
# 1029  https://medium.com/@j_lim_j/summary-of-codesch...      0
# 1030  https://medium.com/human-learning/is-the-end-n...      1
# 1031  https://medium.com/coding-overload/introductio...      0
# 1032  https://medium.com/@cclemensjr/learning-journa...      4
# 1033  https://medium.com/@conshus/day-37-meowpurrdy-...      0
# 1034  https://medium.com/@lgreenberg23/i-forgot-my-p...      0
# 1035  https://medium.com/@emilyldeans/thinking-throu...      0
#
#               lowercase author
# 1                  emily deans
# 2               verity honebon
# 3                   emily chai
# 4              jackson mcgehee
# 5                 bree jackson
# 6                sara jo helba
# 7                emmanuel amon
# 8                    sam foong
# 9              joseph cardillo
# 10                    joe andy
# 11              le wagon tokyo
# 12                 emily deans
# 13                 gabe wright
# 14            chibueze ukaegbu
# 15                zaynaib giwa
# 16              rhys woodberry
# 17                angela wolff
# 18              monica kosciuk
# 19                 jacob moore
# 20              taylor edwards
# 21                  mike brave
# 22               it’s jennilyn
# 23             brigit rossbach
# 24               timika downes
# 25              sam pellegrene
# 26                hack reactor
# 28               kalen hammann
# 29                yonko kilasi
# 30            kamrin klauschie
# 31                chung nguyen
# ...                        ...
# 996              drew campbell
# 997           ethan r. roberts
# 998          divyansh tripathi
# 1000              leibel hecht
# 1001          jonathan jackson
# 1002          berkan asanovski
# 1003                  max lowe
# 1004  francesco pio squillante
# 1005              matt mcmahon
# 1009                 angelhack
# 1010             clint schmidt
# 1011            verity honebon
# 1012                  codeclan
# 1015              hack reactor
# 1016            anthony jarina
# 1018              hack reactor
# 1019             mario posadas
# 1021             caleb harnell
# 1024               kenneth teh
# 1025                   conshus
# 1026          aaron blackshear
# 1027               nabil yafai
# 1028               emily deans
# 1029                     j.lim
# 1030          chris fellingham
# 1031     nicholas vincent-hill
# 1032           charles clemens
# 1033                   conshus
# 1034          lauren greenberg
# 1035               emily deans
#
# [926 rows x 10 columns]

# %% [markdown]
# Now I need to get the first name of the author in "lowercase author" in order to put it through the gender function.

# %%
new_codingdf["first name"] = new_codingdf["lowercase author"].str.split(' ').str.get(0)
new_codingdf.head()
# Out:
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             author                                         author_bio  \
# 1      Emily Deans  Washington, D.C.-based web developer. Former c...
# 2   Verity Honebon                                                NaN
# 3       Emily Chai  A student at Maker’s, aspiring full stack deve...
# 4  Jackson McGehee  Web Dev | Software Engineer | Creative Strateg...
# 5     Bree Jackson                                                NaN
#
#                                                title                 date  \
# 1      Middleware/End of Week – Emily Deans – Medium  2017-07-28 20:01:22
# 2  Week 6 — working in groups (Airbnb clone) – Ve...  2017-07-31 10:57:36
# 3  Hunting for a first job as a developer – Emily...  2017-05-13 10:44:31
# 4  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine – ...  2018-02-02 17:30:29
# 5  This is a homework assignment you see. – Bree ...  2017-08-11 03:11:39
#
#   publisher                                               text  \
# 1    medium  Middleware/ End of Week The last few days we’v...
# 2    medium  Week 6 — working in groups ( Airbnb clone) The...
# 3    medium  Hunting for a first job as a developer Passing...
# 4    medium  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine I ...
# 5    medium  This is a homework assignment you see. As a po...
#
#                                                 tags  \
# 1  ['JavaScript', 'Lesbians Who Tech', 'Women Who...
# 2  ['Agile', 'Codingbootcamp', 'Coding', 'Teamwor...
# 3  ['Job Hunting', 'Developer', 'Makersacademy', ...
# 4  ['Web Development', 'JavaScript', 'Codingbootc...
# 5  ['Life', 'Codingbootcamp', 'Friends', 'Journey...
#
#                                                  url  score lowercase author  \
# 1  https://medium.com/@emilyldeans/middleware-end...      0      emily deans
# 2  https://medium.com/@verityhonebon/week-6-worki...      1   verity honebon
# 3  https://medium.com/@emilyxchai/hunting-for-a-f...      0       emily chai
# 4  https://medium.com/@jacksonfullstack/notes-fro...      0  jackson mcgehee
# 5  https://medium.com/@breejax/as-a-possible-futu...      0     bree jackson
#
#   first name
# 1      emily
# 2     verity
# 3      emily
# 4    jackson
# 5       bree

# %% [markdown]
# Now put it through the gender function

# %%
new_codingdf["gender"] = new_codingdf["first name"].apply(sex_from_name)
new_codingdf["prob_female"] = new_codingdf["first name"].apply(prob_female_from_name)
new_codingdf["prob_male"] = new_codingdf["first name"].apply(prob_male_from_name)
# Out:
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
new_codingdf.head()
# Out:
#             author                                         author_bio  \
# 1      Emily Deans  Washington, D.C.-based web developer. Former c...
# 2   Verity Honebon                                                NaN
# 3       Emily Chai  A student at Maker’s, aspiring full stack deve...
# 4  Jackson McGehee  Web Dev | Software Engineer | Creative Strateg...
# 5     Bree Jackson                                                NaN
#
#                                                title                 date  \
# 1      Middleware/End of Week – Emily Deans – Medium  2017-07-28 20:01:22
# 2  Week 6 — working in groups (Airbnb clone) – Ve...  2017-07-31 10:57:36
# 3  Hunting for a first job as a developer – Emily...  2017-05-13 10:44:31
# 4  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine – ...  2018-02-02 17:30:29
# 5  This is a homework assignment you see. – Bree ...  2017-08-11 03:11:39
#
#   publisher                                               text  \
# 1    medium  Middleware/ End of Week The last few days we’v...
# 2    medium  Week 6 — working in groups ( Airbnb clone) The...
# 3    medium  Hunting for a first job as a developer Passing...
# 4    medium  Notes from U̶n̶d̶e̶r̶g̶r̶o̶u̶n̶d̶ Week Nine I ...
# 5    medium  This is a homework assignment you see. As a po...
#
#                                                 tags  \
# 1  ['JavaScript', 'Lesbians Who Tech', 'Women Who...
# 2  ['Agile', 'Codingbootcamp', 'Coding', 'Teamwor...
# 3  ['Job Hunting', 'Developer', 'Makersacademy', ...
# 4  ['Web Development', 'JavaScript', 'Codingbootc...
# 5  ['Life', 'Codingbootcamp', 'Friends', 'Journey...
#
#                                                  url  score lowercase author  \
# 1  https://medium.com/@emilyldeans/middleware-end...      0      emily deans
# 2  https://medium.com/@verityhonebon/week-6-worki...      1   verity honebon
# 3  https://medium.com/@emilyxchai/hunting-for-a-f...      0       emily chai
# 4  https://medium.com/@jacksonfullstack/notes-fro...      0  jackson mcgehee
# 5  https://medium.com/@breejax/as-a-possible-futu...      0     bree jackson
#
#   first name gender prob_female   prob_male
# 1      emily      F    0.997932  0.00206823
# 2     verity      F           1           0
# 3      emily      F    0.997932  0.00206823
# 4    jackson      M  0.00264886    0.997351
# 5       bree      F    0.997997   0.0020033

# %%
new_codingdf["gender"].value_counts()
# Out:
# M          493
# F          224
# Unknown    209
# Name: gender, dtype: int64

# %% [markdown]
# We have quite a few unknowns in our dataset (almost one fourth, so let's just take a look at these values)

# %%
new_codingdf[new_codingdf["gender"] == "Unknown"]
# Out:
#                          author  \
# 15                 Zaynaib Giwa
# 22                it’s jennilyn
# 26                 Hack Reactor
# 29                 Yonko Kilasi
# 35                Team Codebase
# 44              Venturi's Voice
# 49                 Sourab Kumar
# 51                    DigitYser
# 58                     SwitchUp
# 59                  L.J. Yockey
# 61                    DigitYser
# 66                    Codeworks
# 67                      conshus
# 70                         Bloc
# 74                  DevMountain
# 79                 Hack Reactor
# 82           Startup Southerner
# 86              Aanyu Deborah O
# 88                            E
# 90                 Hack Reactor
# 91                     Modestas
# 95                     SwitchUp
# 101               it’s jennilyn
# 105   Álvaro González San Pedro
# 109                     conshus
# 112                 Careerscore
# 123              Shofi Bahalwan
# 126           Bootcamp Advisors
# 136                    Simonxca
# 137                    Horizons
# ...                         ...
# 899                   Codeworks
# 900                        Eazi
# 903                Hack Upstate
# 905                Hack Reactor
# 906                Hack Reactor
# 908                    V School
# 914                    Horizons
# 925                   HackerYou
# 926                     conshus
# 927             Academy Student
# 931                     conshus
# 935                Hack Reactor
# 941           Institute of Code
# 945                Leibel Hecht
# 946              Nakuya Bridget
# 967               DevPoint Labs
# 968                 jordangonen
# 972                   Codeworks
# 974                    Horizons
# 980                 L.J. Yockey
# 984                NEXT Academy
# 1000               Leibel Hecht
# 1002           Berkan Asanovski
# 1009                  AngelHack
# 1012                   CodeClan
# 1015               Hack Reactor
# 1018               Hack Reactor
# 1025                    conshus
# 1029                      J.Lim
# 1033                    conshus
#
#                                              author_bio  \
# 15    Full Stack Developer | Aspiring Data Scientist...
# 22    Proud to be a #WomanInTech. Software developer...
# 26    Providing the 21st century CS degree. We turn ...
# 29                                                  NaN
# 35    We're a 9-week iOS Training Lab and app develo...
# 44    Blogging and podcasting about all things tech....
# 49    20 yrs | Co-Founder of Buzy Developers | Freel...
# 51    DigitYser is the digital flagship of Brussels ...
# 58    Discover the best learning path to your dream ...
# 59    Full-Stack Developer. Thinkful grad. I like to...
# 61    DigitYser is the digital flagship of Brussels ...
# 66    The leading JavaScript bootcamp in Europe. We ...
# 67    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 70    An online education company with coding and de...
# 74    DevMountain is an industry-leading tech bootca...
# 79    Providing the 21st century CS degree. We turn ...
# 82    On a mission to include, inform and empower th...
# 86                                                  NaN
# 88                                                  NaN
# 90    Providing the 21st century CS degree. We turn ...
# 91                                                  NaN
# 95    Discover the best learning path to your dream ...
# 101   Proud to be a #WomanInTech. Software developer...
# 105   EMEA Expansion Lead @Ironhack. Education passi...
# 109   the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 112   We empower tech professionals to make sound, d...
# 123      Numberphile. Computerphile. Autodidact. Idiot.
# 126   Your personal coach sharing advice to guide yo...
# 136   www.github.com/simonxca | www.twitter.com/simo...
# 137                                                 NaN
# ...                                                 ...
# 899   The leading JavaScript bootcamp in Europe. We ...
# 900                                                 NaN
# 903   Advancing Upstate New York's tech community th...
# 905   Providing the 21st century CS degree. We turn ...
# 906   Providing the 21st century CS degree. We turn ...
# 908   Human Centered Edtech® // An edit on #techlife...
# 914                                                 NaN
# 925   Hands-on, project-based learning. Proven resul...
# 926   the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 927        An account for the students to publish blogs
# 931   the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 935   Providing the 21st century CS degree. We turn ...
# 941                                                 NaN
# 945   I’m Leibel. I’m transitioning from Talmud to T...
# 946                 Life too short we haffi cherish it.
# 967   Helping passionate people launch a career in f...
# 968   think for yourself. http://jordangonen.com/ vi...
# 972   The leading JavaScript bootcamp in Europe. We ...
# 974                                                 NaN
# 980   Full-Stack Developer. Thinkful grad. I like to...
# 984   We are South East Asia’s best tech school focu...
# 1000  I’m Leibel. I’m transitioning from Talmud to T...
# 1002                                 Sometimes i write…
# 1009  AngelHack ignites the passion of the world's m...
# 1012  16-week intensive and part-time software devel...
# 1015  Providing the 21st century CS degree. We turn ...
# 1018  Providing the 21st century CS degree. We turn ...
# 1025  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1029  Learning JavaScript, Vue.js, Sass, Python, Dja...
# 1033  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
#
#                                                   title                 date  \
# 15        Learning How to Learn – Zaynaib Giwa – Medium  2017-10-02 05:37:17
# 22    (Insert weird analogy here) for Git – it’s jen...  2017-06-02 01:40:41
# 26    4 Reasons to Learn to Code You Probably Didn’t...  2018-03-01 19:31:58
# 29    A place with a difference – Yonko Kilasi – Medium  2017-03-02 13:35:43
# 35    Find the Right Coding Bootcamp for You – Team ...  2018-05-10 16:39:17
# 44    Node University: Taking the non-academic route...  2018-07-03 08:42:55
# 49    New Journey of Algorithms and Data Structures ...  2018-08-24 10:34:59
# 51    Shift your career with a Data Science Bootcamp...  2017-07-02 17:09:36
# 58    Coding Bootcamp: A Guide to Help You Choose – ...  2018-05-21 17:47:41
# 59    The Challenges of CSS After Learning Nodejs – ...  2017-06-05 03:50:37
# 61    Ready for our first Data Science Job Fair of 2...  2017-07-12 20:50:31
# 66    Finding a Developer Job That Fits – Code Words...  2018-10-03 13:38:28
# 67                   Day 16 — #Goals – conshus – Medium  2017-04-03 12:08:45
# 70    Why You Should Enroll in a Coding Bootcamp – N...  2017-07-06 03:06:46
# 74    Bootcamp vs Self Taught – The DevMountain Blog...  2017-01-03 21:07:14
# 79    Hack Reactor Becomes Even Better with Acquisit...  2018-08-02 13:01:01
# 82    Southern Startup Report: Iron Yard shuts down,...  2017-07-31 12:43:32
# 1018  Alumni Spotlight: Dylan Shelters’ Journey from...  2018-08-14 13:01:01
# 1025            Day 58 — This is it! – conshus – Medium  2017-06-01 10:51:53
# 1029  Summary of CodeSchool's "Try jQuery" – J.Lim –...  2018-05-24 15:56:25
# 1033             Day 37 — Meowpurrdy – conshus – Medium  2017-05-02 12:09:22
#
#      publisher                                               text  \
# 15      medium  Learning How to Learn I recently finished the ...
# 22      medium  ( Insert weird analogy here) for Git Where I c...
# 26      medium  4 Reasons to Learn to Code You Probably Didn’t...
# 29      medium  A place with a difference Hello I’m Yonko . A ...
# 35      medium  Find the Right Coding Bootcamp for You What to...
# 44      medium  Node University: Taking the non-academic route...
# 49      medium  New Journey of Algorithms and Data Structures ...
# 51      medium  Shift your career with a Data Science Bootcamp...
# 58      medium  Coding Bootcamp: A Guide to Help You Choose In...
# 59      medium  The Challenges of C S S After Learning Nodejs ...
# 61      medium  Ready for our first Data Science Job Fair of 2...
# 66      medium  Finding a Developer Job That Fits What to expe...
# 67      medium  Day 16 — # Goalsliner notes:- What a weekend. ...
# 70      medium  Why You Should Enroll in a Coding Bootcamp Her...
# 74      medium  Bootcamp vs Self Taught Learning to code, as y...
# 79      medium  Hack Reactor Becomes Even Better with Acquisit...
# 82      medium  Southern Startup Report: Iron Yard shuts down,...
# 86      medium  W H Y I C O D E Growing up, i was taught that ...
# 88      medium  Codesmith Weeks 1–2: The first two weeks of Co...
# 90      medium  How Are React J S & Flux J S Related? If you’v...
# 91      medium  General Assembly, Web Development Immersive — ...
# 95      medium  Study at a Bootcamp That Guarantees You a Job ...
# 101     medium  Pilot: Starting my coding journey Hey, I’m Jen...
# 105     medium  The dutch dream; or why tech talent is moving ...
# 109     medium  Day 80 / Feels Goodliner notes: Professional: ...
# 112     medium  What is a Growth Hacker and how to become one ...
# 123     medium  On my way Music recommendation: Phil Collin’s,...
# 126     medium  Brand, Learning, or Network? With the announce...
# 136     medium  Web Dev Lesson 2 - The 2 H T M L Elements You ...
# 137     medium  Horizons, Chapter 6 The “ Aha” Moment when you...
# ...        ...                                                ...
# 899     medium  4 Killer Tips For Hackathon Success What did w...
# 900     medium  Be consistent, stay hungry It has been an even...
# 903     medium  Announcing Hack Upstate’s Careers in Code! A c...
# 905     medium  4 Tips for Sticking to Your Budget While Atten...
# 906     medium  Alumni Spotlight: Jeffrey Sun Empowers Others ...
# 908     medium  Big Week = Big Thanks Last week we were honore...
# 914     medium  Coding Bootcamp Cost: Can I Afford This? Codin...
# 925     medium  Life Lessons from Three Shopify Execs Last wee...
# 926     medium  Day 19 — The Heartliner notes:- Yesterday was ...
# 927     medium  Academy student Josh talks self study vs codin...
# 931     medium  Day 18 — I Can See Clearly Nowliner notes:- Ye...
# 935     medium  How to Know If You Should Go to a Remote Codin...
# 941     medium  Are Coding Bootcamps a Scam!? ( Is Institute o...
# 945     medium  My first app!! but first, a blogging refresh H...
# 946     medium  “ Django girls made me a better girl”“ They sa...
# 967     medium  Why Dev Point Labs Coding School Offers Free H...
# 968     medium  On Working Very Hard One of the biggest qualit...
# 972     medium  New generation of women in tech Future Funded ...
# 974     medium  Where Can I Learn to Code? Where can I learn t...
# 980     medium  React and A P Is This week felt like Hell Week...
# 984     medium  Why We’ve ( Re-) Started Interviewing Students...
# 1000    medium  Portfolio is live! Plus apps are mobile friend...
# 1002    medium  Why you should pay for a Coding Boot camp, or ...
# 1009    medium  Deciding Between a Bachelor’s Degree and Codin...
# 1012    medium  How we got an app on the Play Store Armed with...
# 1015    medium  Are Online Coding Bootcamps Still Important in...
# 1018    medium  Alumni Spotlight: Dylan Shelters’ Journey from...
# 1025    medium  Day 58 — This is it!liner notes: Yesterday, mo...
# 1029    medium  Summary of Code School’s “ Try j Query” J L’s ...
# 1033    medium  Day 37 — Meowpurrdyliner notes: So yesterday, ...
#
#                                                    tags  \
# 15    ['Productivity', 'Codingbootcamp', 'Codelikeag...
# 22    ['Git', 'The Iron Yard', 'Learning To Code', '...
# 26    ['Programming', 'Coding', 'Code', 'Learning To...
# 29    ['Education', 'Teaching', 'Technology', 'Codin...
# 35    ['Programming', 'Coding', 'Codingbootcamp', 'E...
# 44    ['Coding', 'Learn To Code', 'Code Newbie', 'Co...
# 49    ['Programming', 'Computer Science', 'Coding', ...
# 51    ['Data Science', 'Bootcamp', 'Career Advice', ...
# 58    ['Programming', 'Codingbootcamp', 'Coding', 'B...
# 59    ['Web Development', 'CSS', 'JavaScript', 'Codi...
# 61    ['Data Science', 'Codingbootcamp', 'Coding', '...
# 66    ['Programming', 'Startup', 'Web Development', ...
# 67             ['Coding', 'Coding Bootcamps', 'Hiphop']
# 70    ['Career Track', 'Software Development', 'Web ...
# 74    ['Programming', 'Coding', 'Coding Bootcamps', ...
# 79    ['Coding', 'Acquisition', 'Galvanize', 'Hack R...
# 82    ['Startup', 'Startupyall', 'Codingbootcamp', '...
# 86    ['Life', 'Codingbootcamp', 'Programming', 'Tec...
# 88    ['Programming', 'Codesmith', 'Coding', 'Coding...
# 90    ['JavaScript', 'Reactjs', 'Flux', 'Coding', 'C...
# 91    ['Programming', 'Codingbootcamp', 'Tech', 'Tec...
# 95    ['Programming', 'Codingbootcamp', 'Coding', 'C...
# 101   ['The Iron Yard', 'Codingbootcamp', 'Coding', ...
# 105   ['Entrepreneurship', 'Netherlands', 'Ironhack'...
# 109   ['Programming', 'Codingbootcamp', 'Hip Hop', '...
# 112     ['Growth Hacking', 'Startup', 'Codingbootcamp']
# 123       ['Programming', 'Bootcamp', 'Codingbootcamp']
# 126   ['Programming', 'Learn To Code', 'Software Dev...
# 136   ['Web Development', 'Learning To Code', 'HTML'...
# 137   ['Startup', 'Venture Capital', 'Technology', '...
# ...                                                 ...
# 899   ['Hackathons', 'Facebook', 'Codingbootcamp', '...
# 900   ['Entrepreneurship', 'Coding', 'Codingbootcamp...
# 903   ['Entrepreneurship', 'Upstate New York', 'Hack...
# 905   ['Programming', 'Coding', 'Codingbootcamp', 'B...
# 906   ['Coding', 'Codingbootcamp', 'JavaScript', 'Al...
# 908   ['Coding', 'React', 'Reactjs', 'Learn Programm...
# 914    ['Programming', 'Codingbootcamp', 'Code School']
# 925   ['Advice', 'Ruby on Rails', 'Coding Bootcamp',...
# 926   ['Coding', 'Codingbootcamp', 'Hip Hop', 'Front...
# 927   ['Programming', 'Codingbootcamp', 'Coding', 'L...
# 931   ['JavaScript', 'Functional Programming', 'Codi...
# 935   ['Programming', 'Coding', 'Codingbootcamp', 'R...
# 941   ['Web Development', 'Web Development Bootcamps...
# 945   ['Web Development', 'Coding Dojo', 'Codingboot...
# 946   ['Django', 'Girls', 'Coding', 'Codingbootcamp'...
# 967   ['Education', 'Learn To Code', 'Free Student H...
# 968                          ['Life', 'Codingbootcamp']
# 972   ['Women In Tech', 'Crowdfunding', 'News', 'Cod...
# 974    ['Programming', 'Code School', 'Codingbootcamp']
# 980   ['JavaScript', 'React', 'API', 'Sql', 'Codingb...
# 984      ['Coding Bootcamp', 'Next Academy', 'Updates']
# 1000  ['Web Development', 'Portfolio', 'Coding', 'Co...
# 1002       ['Bootcamp', 'Codingbootcamp', 'Connection']
# 1009  ['Programming', 'Codingbootcamp', 'Coding', 'E...
# 1012  ['Android', 'Coding', 'Codingbootcamp', 'Learn...
# 1015  ['Programming', 'Coding', 'Codingbootcamp', 'R...
# 1018  ['Hack Reactor', 'React', 'Engineering', 'Prog...
# 1025  ['Hip Hop', 'Coding', 'Code', 'Codingbootcamp'...
# 1029  ['JavaScript', 'Jquery', 'Code School', 'Codin...
# 1033  ['Firebase', 'Code', 'Coding', 'Codingbootcamp...
#
#                                                     url  score  \
# 15    https://medium.com/@zaynaibg/learning-how-to-l...      0
# 22    https://medium.com/@jennilynhowell/insert-weir...      0
# 26    https://medium.com/@hackreactor/4-reasons-to-l...      0
# 29    https://medium.com/@yonkokilasi/a-place-with-a...      0
# 35    https://medium.com/@codebasesaga/find-the-righ...      6
# 44    https://medium.com/@venturimarketingliam/node-...      1
# 49    https://medium.com/buzy-developers/new-journey...      6
# 51    https://medium.com/@DigitYser/shift-your-caree...      5
# 58    https://medium.com/@switchup/coding-bootcamp-a...      2
# 59    https://medium.com/@Ljyockey/why-going-back-to...      0
# 61    https://medium.com/@DigitYser/ready-for-our-fi...      0
# 66    https://medium.com/code-words/finding-a-develo...      2
# 67    https://medium.com/@conshus/day-16-goals-56c7b...      0
# 70    https://medium.com/newsonthebloc/why-you-shoul...      6
# 74    https://medium.com/devmountain/bootcamp-vs-sel...      2
# 79    https://medium.com/@hackreactor/hack-reactor-b...      0
# 82    https://medium.com/@StartupSoutherner/southern...      1
# 86    https://medium.com/@aanyudeboraho/why-i-code-2...      1
# 88    https://medium.com/@eternally/codesmith-weeks-...      0
# 90    https://medium.com/@hackreactor/how-are-react-...      0
# 91    https://medium.com/@kmodestas/general-assembly...      0
# 95    https://medium.com/@switchup/study-at-a-bootca...      0
# 101   https://medium.com/@jennilynhowell/pilot-start...      2
# 105   https://medium.com/ironhack/https-medium-com-a...     11
# 70                         bloc         bloc  Unknown     Unknown   Unknown
# 74                  devmountain  devmountain  Unknown     Unknown   Unknown
# 79                 hack reactor         hack  Unknown     Unknown   Unknown
# 82           startup southerner      startup  Unknown     Unknown   Unknown
# 86              aanyu deborah o        aanyu  Unknown     Unknown   Unknown
# 88                            e            e  Unknown     Unknown   Unknown
# 90                 hack reactor         hack  Unknown     Unknown   Unknown
# 91                     modestas     modestas  Unknown     Unknown   Unknown
# 95                     switchup     switchup  Unknown     Unknown   Unknown
# 101               it’s jennilyn         it’s  Unknown     Unknown   Unknown
# 105   álvaro gonzález san pedro       álvaro  Unknown     Unknown   Unknown
# 109                     conshus      conshus  Unknown     Unknown   Unknown
# 112                 careerscore  careerscore  Unknown     Unknown   Unknown
# 123              shofi bahalwan        shofi  Unknown     Unknown   Unknown
# 126           bootcamp advisors     bootcamp  Unknown     Unknown   Unknown
# 136                    simonxca     simonxca  Unknown     Unknown   Unknown
# 137                    horizons     horizons  Unknown     Unknown   Unknown
# ...                         ...          ...      ...         ...       ...
# 899                   codeworks    codeworks  Unknown     Unknown   Unknown
# 900                        eazi         eazi  Unknown     Unknown   Unknown
# 903                hack upstate         hack  Unknown     Unknown   Unknown
# 905                hack reactor         hack  Unknown     Unknown   Unknown
# 906                hack reactor         hack  Unknown     Unknown   Unknown
# 908                    v school            v  Unknown     Unknown   Unknown
# 914                    horizons     horizons  Unknown     Unknown   Unknown
# 925                   hackeryou    hackeryou  Unknown     Unknown   Unknown
# 926                     conshus      conshus  Unknown     Unknown   Unknown
# 927             academy student      academy  Unknown     Unknown   Unknown
# 931                     conshus      conshus  Unknown     Unknown   Unknown
# 935                hack reactor         hack  Unknown     Unknown   Unknown
# 941           institute of code    institute  Unknown     Unknown   Unknown
# 945                leibel hecht       leibel  Unknown     Unknown   Unknown
# 946              nakuya bridget       nakuya  Unknown     Unknown   Unknown
# 967               devpoint labs     devpoint  Unknown     Unknown   Unknown
# 968                 jordangonen  jordangonen  Unknown     Unknown   Unknown
# 972                   codeworks    codeworks  Unknown     Unknown   Unknown
# 974                    horizons     horizons  Unknown     Unknown   Unknown
# 980                 l.j. yockey         l.j.  Unknown     Unknown   Unknown
# 984                next academy         next  Unknown     Unknown   Unknown
# 1000               leibel hecht       leibel  Unknown     Unknown   Unknown
# 1002           berkan asanovski       berkan  Unknown     Unknown   Unknown
# 1009                  angelhack    angelhack  Unknown     Unknown   Unknown
# 1012                   codeclan     codeclan  Unknown     Unknown   Unknown
# 1015               hack reactor         hack  Unknown     Unknown   Unknown
# 1018               hack reactor         hack  Unknown     Unknown   Unknown
# 1025                    conshus      conshus  Unknown     Unknown   Unknown
# 1029                      j.lim        j.lim  Unknown     Unknown   Unknown
# 1033                    conshus      conshus  Unknown     Unknown   Unknown
#
# [209 rows x 14 columns]

# %% [markdown]
# We can see that many of the authors in this part are different schools/workshops/organizations that we missed out on earlier, or they are more international type of names, or they are names with a letter for the first name followed by the full last name (these we may have to go through by hand in order to determine gender). Many are also from an author called "conshus"
