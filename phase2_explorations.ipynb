# %% [markdown]
# # Phase 2 Explorations

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import re
import dateutil.parser
import datetime

# %%
article_info = pd.read_csv("codingbootcamp_articles_info.csv")
article_info.head()
# Out:
#    Unnamed: 0                  author  \
# 0           0         William Elliott
# 1           1                     NaN
# 2           2  Kimberly Lowe-Williams
# 3           3        Haseeb Chaudhary
# 4           4  Clifford Armstrong III
#
#                                           author_bio  \
# 0  Software Engineer passionate about learning, b...
# 1                                                NaN
# 2  CEO/Executive Director of The Difference Engin...
# 3  Cyber Security Architect https://www.linkedin....
# 4                                                NaN
#
#                                                title  \
# 0            Hello World! – William Elliott – Medium
# 1                                                NaN
# 2  The Future is Now! – Kimberly Lowe-Williams – ...
# 3  The Beautiful Struggle – Haseeb Chaudhary – Me...
# 4  How I’m faking it till I make it. – Clifford A...
#
#                        date publisher  \
# 0  2017-07-09T16:26:46.739Z    medium
# 1                       NaN       NaN
# 2  2017-12-02T11:01:01.804Z    medium
# 3  2018-07-08T08:42:33.881Z    medium
# 4  2018-08-31T01:43:41.476Z    medium
#
#                                                 text
# 0  Hello World!image sourceMy name is Will and I ...
# 1                                                NaN
# 2  The Future is Now!For years we have heard abou...
# 3  The Beautiful StruggleIt’s been four months si...
# 4  How I’m faking it till I make it.One of the co...
