# %% [markdown]
# # Cleaned Parsing Functions

# %%
# Import necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from requests import get
from requests.exceptions import RequestException
from contextlib import closing
from bs4 import BeautifulSoup
import re
import dateutil.parser
import datetime
import json

# %% [markdown]
# ## Overview

# %% [markdown]
# Our goal is to extract relevant information on every article tagged with the `Codingbootcamp` tag.
# We accomplish this in three steps:
# 1. Iterate through each page of the archive for this tag.
# 2. On each date page (such as 2018/01/02), extract the urls for all links that correspond to articles published on that date tagged with `Codingbootcamp` (don't extract "Home", "signup" links etc).
# 3. On each url, call the single article parsing function to extract author, author_bio, title, publish date, publisher, and article text.

# %% [markdown]
# ## Get HTML Function
# **Base Source**: https://realpython.com/python-web-scraping-practical-introduction/
# **Update10/1/18**: This code originated from this tutorial but was later adapted in order complete step 3 - to get all articles tagged with `Codingbootcamp`.
# I added a second get html function that checked whether the web browser redirected you at some point when attempting to access the html at the provided link. This was necessary because when you attempted to access a page of the archive that didn't exist - such as attempting to access `archive/2013/03/02`, you are instead redirected back to the year or month page. In those situations, I didn't want to re-parse the articles on the main page, which would have been redundant parsing (and extra time in an already long function, and instead didn't parse a page that had been redirected.
# I had to keep this in a seperate function, because for certain single article urls, like "https://medium.freecodecamp.org/5-key-learnings-from-the-post-bootcamp-job-search-9a07468d2331" were redirected in the retreival process (I am not sure why). I attempted to come up with a elegant solution using response object attributes that would differentiate between article redirects and archive redirects, but was unable to do so.
# So the function that retrieves the html for articles doesn't check for redirects, but the function that retrieves archive page html does check for redirects.

# %%
# Define get function to get raw HTML
def simple_get_article(url):
    """
    Attempts to get the content at `url` by making an HTTP GET request.
    If the content-type of response is some kind of HTML/XML, return the
    text content, otherwise return None.
    """
    try:
        #closing ensures any network resources are freed when out of scope - good practice
        with closing(get(url, stream=True)) as resp: 
            if is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None

# Define get function to get raw HTML from the archive pages, with a twist.
def simple_get_archive(url):
    """
    Retrieves the raw html of a page in the `Codingbootcamp` tag archive (https://medium.com/tag/codingbootcamp/archive).
    But some pages of the archive don't exist (like 2013/01/02) because no stories were published on that date. 
    If you attempt to access these nonexistent urls, you are redirected to the main year or month page.
    We don't want to re-parse those pages (redundant code), so our hack-y solution is to check to see if the HTML response
    object has a redirect (302 status code) in its history. 
    This is defined as a separate function, because some of the article urls are redirected (I am not sure why), and I couldn't 
    come up with a clean solution that separates article redirection vs archive redirection. 
    """
    try:
        #closing ensures any network resources are freed when out of scope - good practice
        with closing(get(url, stream=True)) as resp: 
            if is_redirect(resp):
                return "redirect"
            elif is_good_response(resp):
                return resp.content
            else:
                return None

    except RequestException as e:
        log_error('Error during requests to {0} : {1}'.format(url, str(e)))
        return None
    
# I added this helper function to check if the HTML response returned by the browser had been redirected at some point
# See http://docs.python-requests.org/en/v0.10.6/api/ for docs on history attribute
def is_redirect(resp):
    """
    Returns True if the resp had been redirected at some point in the retrieval process due to nonexistent url, 
    False otherwise. 
    Arguments: a HTML response object
    """
    resp_history = resp.history
    if resp_history: #not empty - some things happend before response was returned
        # I specifically want to check for redirects (status code 302)
        statuses = [h.status_code==302 for h in resp_history]
        # Are there any true in the above list comp? Then something was redirected. 
        return np.any(statuses)
    else:
        return False
    
def is_good_response(resp):
    """
    Returns True if the response seems to be HTML, False otherwise.
    """
    content_type = resp.headers['Content-Type'].lower()
    return (resp.status_code == 200 
            and content_type is not None 
            and content_type.find('html') > -1)


def log_error(e):
    """
    It is always a good idea to log errors. 
    This function just prints them, but you can
    make it do anything.
    """
    print(e)

# %% [markdown]
# ## Single Article Info Parsing

# %% [markdown]
# The following functions return information parsed from a single article on Medium.

# %%
def get_author(parsed_html):
    """Parses the author name from a Medium article. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        the author name as a string or None if author tag not present
    """
    author = parsed_html.find('meta', property="author")
    return author['content'] if author else None

def get_author_bio(parsed_html):
    """Parses the author's bio/description from a Medium article. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        the author bio/description as a string if it exists, and None otherwise
    """
    bios = parsed_html.find_all('div', class_="ui-caption ui-xs-clamp2 postMetaInline")
    # If bios is empty, that means there is no author bio for article, and the [0]  will error so we need to explicityly
    # check and return None if no author bio
    return bios[0].text if bios else None

def get_title(parsed_html):
    """Parses the title of a Medium article.
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        the title of the article as a string or None if title tag not present
    """
    title = parsed_html.find('meta', property='og:title')
    return title['content'] if title else None

def get_raw_publish_date(parsed_html):
    """Parses the date a Medium article was published. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns: 
        a raw/uncleaned publish date, which looks like '2016-11-19T16:48:30.365Z', or None if tag not present
    """
    date = parsed_html.find('meta', property='article:published_time')
    return date['content'] if date else None

def get_article_publisher(parsed_html):
    """Parses the article's publisher from a Medium article. 
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Notes:
        The publisher is encoded as "https://facebook.com/publisher" so I extract just the publisher name.
        Not all articles have a verified publisher - like if it's just the author's personal blog - so publisher is
        just "medium" in that case
    Returns:
        If article is hosted on verified publisher, returns publisher name as string
        If article is on personal blog, returns "medium" as a string. 
        If publisher tag doesn't exist, returns None
        
    """
    long_publisher = parsed_html.find("meta", property='article:publisher')
    return long_publisher['content'].split("/")[3] if long_publisher else None

def get_raw_article_text(parsed_html):
    """Extracts out the text/content of the Medium article.
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Returns:
        a raw/uncleaned string of text or None if tag is not present.
        The string is considered "raw" because there are some weird characters that are remants
        of header formatting and the like.
    """
    text = parsed_html.find_all('div', class_='postArticle-content')
    return text[0].text if text else None

def clean_text(text):
    """takes a string of text
    removes \xa0 and \u200a that are randomly splattered throughout text
    adds spaces after punctuation that appeared to be missing
    splits all words where a capital letter is in the middle of a word and puts a space in front of it and removes double spaces
    """
    if text:
        cleaned_text = text.replace("\xa0", " ").replace("\u200a", " ")
        cleaned_text = re.sub(r'(?<=[.,])(?=[^\s])', r' ', cleaned_text)
        cleaned_text = re.sub(r'([A-Z])', r' \1', cleaned_text).lstrip().replace("  ", " ")
        return cleaned_text
    else:
        # text is a None object which you can't use regex on.
        return text

def clean_date(date):
    """takes a string in RFC 339 format ('Y-M-D"T"H:M:S.MS"Z"')
    returns a string of format ('Y-M-D H:M:S')
    """
    if date:
        date = dateutil.parser.parse(date)
        date = date.strftime("%Y-%m-%d %H:%M:%S")
        return date
    else:
        # Date is a None object and you can't parse it
        return date
    
def get_tags(parsed_html):
    script_html = parsed_html.find("script", type='application/ld+json')
    script_data = json.loads(script_html.text)
    keywords_list = script_data['keywords']
    tags = []
    for elem in keywords_list:
        if elem.startswith("Tag:"):
            tags.append(elem[4:])
    return tags

def get_url(parsed_html):
    url = parsed_html.find("meta", property="al:web:url")
    return url["content"]


def get_all_article_info(article_url):
    """Parses a Medium article to get all needed information about author and story.
    Arguments:
        article_url: String of url for article to parse
    Returns:
        list of [author, author_bio, title, date, publisher article_text], where each component is a string or None
    """
    raw_html = simple_get_article(article_url)
    parsed_html = BeautifulSoup(raw_html, 'html.parser')
    author = get_author(parsed_html)
    author_bio = get_author_bio(parsed_html)
    title = get_title(parsed_html)
    raw_date = get_raw_publish_date(parsed_html)
    cleaned_date = clean_date(raw_date)
    publisher = get_article_publisher(parsed_html)
    raw_text = get_raw_article_text(parsed_html)
    cleaned_text = clean_text(raw_text)
    tags = get_tags(parsed_html)
    url = get_url(parsed_html)
    return [author, author_bio, title, cleaned_date, publisher, cleaned_text, tags, url]

# %%
## working on getting the tags of the article
# article_url = "https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38"
# raw_html = simple_get_article(article_url)
# parsed_html = BeautifulSoup(raw_html, 'html.parser')
# # print(parsed_html)
# script_html = parsed_html.find("script", type='application/ld+json')
# long_publisher = parsed_html.find("meta", property='article:publisher')['content']
# # print(long_publisher)
# ## extract content of script https://stackoverflow.com/questions/26192727/extract-content-of-script-with-beautifulsoup
# script_data = json.loads(script_html.text)
# keywords_list = script_data['keywords']
# tags = []
# for elem in keywords_list:
#     if elem.startswith("Tag:"):
#         tags.append(elem[4:])
# # print(tags)

# def get_tags(parsed_html):
#     script_html = parsed_html.find("script", type='application/ld+json')
#     script_data = json.loads(script_html.text)
#     keywords_list = script_data['keywords']
#     tags = []
#     for elem in keywords_list:
#         if elem.startswith("Tag:"):
#             tags.append(elem[4:])
#     return tags

# get_tags(parsed_html)

# %%
## working on getting the url
# article_url = "https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38"
# raw_html = simple_get_article(article_url)
# parsed_html = BeautifulSoup(raw_html, 'html.parser')
# def get_url(parsed_html):
#     url = parsed_html.find("meta", property="al:web:url")
#     return url["content"]
# get_url(parsed_html)

# %% [markdown]
# ### Single Article Example Usage

# %%
test_url_1 = "https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38"
get_all_article_info(test_url_1)
# Out:
# ['Chris Lee',
#  None,
#  "We're Not a Bootcamp – Launch School – Medium",
#  '2018-08-01 01:48:19',
#  'medium',
#  'We’re Not a Bootcamp We’re Something Unique, and Uniquely Effective Photo by Kyle Johnson on Unsplash One of the things about operating in a crowded marketplace is that you tend to get lumped in with the biggest names and most common stereotypes. In the programming education space, that means the now familiar label of “bootcamp. ” I often see people refer to Launch School as a “coding bootcamp, ” which may seem like a reasonable shortcut for helping people understand what we do; however, it fails to capture what makes us special. When I talk about Launch School and what we are trying to achieve, I don’t use the word “bootcamp. ” We are an online school for developers, but more than that, we are a school with an opinionated pedagogy that focuses on fundamentals first with the goal of building skills that last a career. So, why do I steer clear of the “bootcamp” label? To put it simply, I don’t believe that it accurately describes our model. Neither our methodology nor our curriculum reflect those of most coding “bootcamps, ” and to be frank, nor do our results. Graduates of our Capstone program are getting jobs with an average salary around $110, 000, as compared to graduates of even the best bootcamps, who in the same markets are averaging salaries around $85, 000. Why is that? The reason is that we are doing something different than what the bootcamps are doing. Launch School is the only online school for developers with a pedagogy that explicitly revolves around mastery-based learning. Plenty of schools, some bootcamps included, talk about the importance of mastering the fundamentals, but we are the only one that is actually putting that claim into practice. And we do this because we firmly believe that mastering fundamentals, first and foremost, is the best way to launch a lifelong career as a software developer. Our mission is to help our students get not just any job, but top jobs, at top companies. Of course, every school and bootcamp out there makes similar claims. So today I want to talk about how Launch School is different and explain why our philosophy leads to better outcomes. The Bootcamp Model Photo by My Photo Journeys on Flickr. C C license. In order to set the stage for understanding Launch School’s philosophy, perhaps we should first take a moment to understand our point of comparison: the bootcamp model. The name of this model itself provides us with a useful starting point. A “bootcamp, ” by common definition, is a short but intense period of training meant to shock the system of people who go through it. The goal is to quickly indoctrinate participants into a new way of thinking and provide them all at once with everything they need to be successful. Most coding bootcamps operate in a roughly analogous fashion, albeit from two starting points. In one model, a bootcamp will accept any and all students who want to join. In the other, bootcamps accept only the “best” students. In both cases though, students enter the program, undergo 8, or 12, or 16, or even 24, weeks of intense instruction, and then exit the program with the hope that they know enough to start going after jobs. For the more selective bootcamps, the hope is that starting with the “best” students will result in a higher percentage of successful graduates; however, even this is an implicit acknowledgement that the model doesn’t work for everyone. In many ways, the bootcamp model is not so very different from the factory-style education model practiced by most of our broader education system. That is, students come in, go through some predefined series of steps over some predefined and non-negotiable schedule, and then come out, ready or not. But what happens when a student moves between steps too soon? What happens when a student “graduates” (meaning primarily that they made it to the end of the program) but hasn’t yet had time to put down the necessary intellectual roots? The problem with the bootcamp model is that it doesn’t provide most lea ...
#  ['Programming',
#   'Coding',
#   'Codingbootcamp',
#   'Learning To Code',
#   'Launch School'],
#  'https://medium.com/launch-school/were-not-a-bootcamp-c33901412c38']

# %% [markdown]
# ### Get all open post links from a page

# %%
def get_all_open_post_links(parsed_html):
    """Retrieves all links on a page that open to an article (does not return "home", "sign up" links etc).
    Arguments:
        parsed_html: object returned by calling `BeautifulSoup(raw_html, 'html.parser')`
    Notes:
        All links on a page that have the data-attribute 'open-post' are the types of links we want.
        find_all returns a special BeautifulSoup object so I need to extract the string url.
        I think there are muliple links for each post (like the title and "read more"), so returning array 
        has duplicates
    Returns:
        List of link strings
    """
    def href_open_post_data_action(tag):
        """Helper parsing function that checks to see if an "a" tag is an href with an 'open-post' data action.
        Arguments:
            tag: All html tags like <a>, <div> that BeautifulSoup has extracted
        Returns:
            true if tag has href and 'open-post' data-action attribute, false otherwise
        """
        return tag.has_attr('href') and tag.get('data-action') == 'open-post'
    
    link_objects =  parsed_html.find_all(href_open_post_data_action)
    return [link.get('href') for link in link_objects] #retrieves the string url from link object

# %% [markdown]
# The above function is the "middle level" function in the grand scheme of our parsing.
# First, we defined the function that parses information for a single article.
# The next step is to retrieve all the links to articles on a web page (like the web page returned by searching "coding bootcamp" for example), and then call our single article parsing function on each link we extracted from the page.
# Note - the name is "open post" links because there are a ton of links on a webpage - to "home", to "sign-up", to "search" etc. We are only interested in extracting the links that correspond to articles about coding bootcamps.
# After inspecting the source html, I discovered that all links that open to coding bootcamp articles have the attribute "data-action" set to "open-post" within the html `<a href>` tag. So this function ensures that it only extracts the links we want.

# %% [markdown]
# ## Iterate Through All Dates in Archive

# %% [markdown]
# The next step is to define a function that will iterate through each "date" page in the archive, gather all the open post links for each "date" page (i.e. all the story links), and then call the single article parser on each link.
# **NOTE**: The following function is currently defined such that it will *ONLY* work on the archive for the `Codingbootcamp` (https://medium.com/tag/codingbootcamp/archive) because currently it operates on the assumption that the years 2013 and 2014 have so few articles that they are not seperated by month or day, only year.

# %%
def format_dates_for_url(integer_date):
    """
    Formats dates to enter into the archive url, which requires numbers < 10 to be encoded with a "0" in front,
    but Python doesn't allow 01 as an integer. 
    """
    if integer_date < 10:
        return str(0) + str(integer_date)
    else:
        return str(integer_date)
def get_specific_Codingbootcamp_links():
    # For current range of years available
    years = range(2013, 2019)
    months_w_o_zero_in_front = range(1, 13)
    days_w_o_zero = range(1, 32)
    base_url = "https://medium.com/tag/codingbootcamp/archive"
    # Collector variable to story all story urls
    story_links = []
    for year in years:
        # These years don't have month, day subdivisions so to prevent redundant parsing, 
        # just parse the base year and its links.
        if year == 2013 or year == 2014:
            # 
            url = base_url + "/" + format_dates_for_url(year)
            raw_year_html = simple_get_archive(url)
            # If raw_year_html is None, can't parse it so skip
            if not raw_year_html:
                break
            parsed_year_html = BeautifulSoup(raw_year_html, 'html.parser')
            links = get_all_open_post_links(parsed_year_html)
            #use extend instead of append because just want to add elements, not create nested lists.
            story_links.extend(links) 
        else:
            for month in months_w_o_zero_in_front:
                for day in days_w_o_zero:
                    url = base_url + "/" + format_dates_for_url(year) + format_dates_for_url(month) + "/" + format_dates_for_url(day)
                    raw_day_html = simple_get_archive(url)
                    # 2015, 2016, 2017, 2018 have some dates with no stories, so GET requests are redirected
                    # and we don't want to parse stuff we already did.
                    if raw_day_html == "redirect":
                        #skip the redirected day - advance in for loop
                        break
                    # If raw_day_html is None, can't parse it so skip
                    elif not raw_day_html:
                        break
                    parsed_day_html = BeautifulSoup(raw_day_html, 'html.parser')
                    links = get_all_open_post_links(parsed_day_html)
                    #use extend instead of append because just want to add elements, not create nested lists.
                    story_links.extend(links)
    # Create a set of links to remove duplicates and then turn back into a list (better data structure)
    return list(set(story_links))

# %% [markdown]
# ### Collect Text Data

# %%
# List of urls for all stories tagged with `Codingbootcamp`
story_links = get_specific_Codingbootcamp_links()

# %%
# Get all info like article, publisher, etc for each url gathered above
# THIS CELL TAKES FOREVER BE WARNED - DO NOT CLOSE COMPUTER WHILE RUNNING ELSE THE CONNECTION BREAKS
story_info_list = []
for url in story_links:
    story_info_list.append(get_all_article_info(url))

# %%
column_names = ["author", "author_bio", "title", "date", "publisher", "text", "tags", "url"]
Codingbootcamp_info = pd.DataFrame(story_info_list, columns = column_names)

# %%
Codingbootcamp_info
# Out:
#                       author  \
# 0              Kalen Hammann
# 1                 Mike Brave
# 2            Irsan Sebastian
# 3                 KeepCoding
# 4      Sabio Coding Bootcamp
# 5                 Mike Brave
# 6           Better Developer
# 7                 adam tropp
# 8             Verity Honebon
# 9           Manchester Codes
# 10           Code Collective
# 11     Sabio Coding Bootcamp
# 12                Ari Kramer
# 13               Erin Levine
# 14                   conshus
# 15                Mike Brave
# 16               Jacob Moore
# 17        Angélica Velázquez
# 18                 Jeff Wong
# 19               Kyle Thayer
# 20                Max Berger
# 21            Robert Furtado
# 22           Natasha Robarge
# 23                       이상훈
# 24           Accelerate Tech
# 25                  Abi Noda
# 26                adam tropp
# 27                Kait Sykes
# 28              Leibel Hecht
# 29                Mike Brave
# ...                      ...
# 1045         Connor Kirkwood
# 1046           Nat Villasana
# 1047                 conshus
# 1048              King Nimmo
# 1049           Mauro Gestoso
# 1050               Dex Mills
# 1051        chibueze ukaegbu
# 1052   Sabio Coding Bootcamp
# 1053        Giannini Charles
# 1054             David Clark
# 1055   Sabio Coding Bootcamp
# 1056            Scott Bowman
# 1057        chibueze ukaegbu
# 1058                 conshus
# 1059                   J.Lim
# 1060         Franziska Luzia
# 1061             Sean Sutton
# 1062            Blake Schlin
# 1063            Chance Taken
# 1064            Swift Snacks
# 1065           Steve Bogucki
# 1066            Kate Walters
# 1067                Sam Kane
# 1068          Tom Goldenberg
# 1069            Rithm School
# 1070              adam tropp
# 1071           Jessica Alves
# 1072  Adriana Höher Dorneles
# 1073             Emily Deans
# 1074             Emily Deans
#
#                                              author_bio  \
# 0                                                  None
# 1     I make things with design and code. Here's to ...
# 2                                                  None
# 3     We create the best learning experience for Ful...
# 4     Lead by the most senior coding bootcamp staff ...
# 5     I make things with design and code. Here's to ...
# 6     Sharing my experience in what it takes to beco...
# 7                                                  None
# 8                                                  None
# 9                                     https://mcr.codes
# 10    Exposing the world to code. Questions/Feedback...
# 11    Lead by the most senior coding bootcamp staff ...
# 12                                                 None
# 13    Pretending to be an adult. Discussin' the ebb ...
# 14    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 15    I make things with design and code. Here's to ...
# 16                                                 None
# 17                                                 None
# 18                                        Web developer
# 19    I am a PhD student studying programming, cultu...
# 20                                                 None
# 21                          Founder of CourseCompare.ca
# 22    Software Consultant | Tech Enthusiast | Fitnes...
# 23                                                 None
# 24                                                 None
# 25    Independent developer and founder of http://pu...
# 26                                                 None
# 27    Web developer via @hackeryou. Slytherin. Popco...
# 28    I’m Leibel. I’m transitioning from Talmud to T...
# 29    I make things with design and code. Here's to ...
# ...                                                 ...
# 1045                                               None
# 1046        digital media artist and software developer
# 1047  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1048  We are Vanessa Nimmo and Celia King. We are ma...
# 1049  Carbon based life form. Angry cyclist. JavaScr...
# 1050                                       dexmills.com
# 1051                                               None
# 1052  Lead by the most senior coding bootcamp staff ...
# 1053                                               None
# 1054  Mindfulness | Humans | Animals | Earth | Codin...
# 1055  Lead by the most senior coding bootcamp staff ...
# 1056                                               None
# 1057                                               None
# 1058  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
#
# 1073             medium  Something that broke my brain A thing I’ve com...
# 1074             medium  Saturday’s a… There was a time in my life when...
#
#                                                    tags  \
# 0     [Web Development, Codingbootcamp, Code Review,...
# 1          [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2     [Story, My Life, Codingbootcamp, Coding, Startup]
# 3     [Programming, Codingbootcamp, Web Development,...
# 4                    [Veterans In Tech, Codingbootcamp]
# 5     [Life Lessons, Ecole 42, Education, Codingboot...
# 6     [Software Development, Learning To Code, Learn...
# 7       [Programming, Codingbootcamp, Computer Science]
# 8     [Programming, Coding, Codingbootcamp, Collabor...
# 9     [Programming, Manchester Codes, Manchester, Co...
# 10    [Programming, Coding, Codingbootcamp, Code, Ed...
# 11    [Programming, Codingbootcamp, Coding, Jobs, Te...
# 12       [Coding, Software Development, Codingbootcamp]
# 13    [JavaScript, Web Development, Coding, Codingbo...
# 14    [Reactjs, Firebase, Coding, Codingbootcamp, Hi...
# 15     [Art, Ecole 42, Code, Education, Codingbootcamp]
# 16                         [JavaScript, Codingbootcamp]
# 17                    [HTML, CSS, Sass, Codingbootcamp]
# 18    [Programming, Career Change, Software Developm...
# 19    [Programming, Computer Science, Codingbootcamp...
# 20    [Productivity, Coding, Hack Reactor, Codingboo...
# 21    [Programming, Digital Marketing, Codingbootcam...
# 22    [Programming, College, Codingbootcamp, Coding,...
# 23    [Codingbootcamp, JavaScript, Function, Front E...
# 24    [Web Development, Programming, Codingbootcamp,...
# 25    [Programming, Codingbootcamp, Web Development,...
# 26    [JavaScript, Codingbootcamp, Programming, Comp...
# 27    [Web Development, Wireframe, Coding, Coding Bo...
# 28    [Data Science, Data, Codingbootcamp, Coding, W...
# 29    [Life Lessons, Ecole 42, Education, Codingboot...
# ...                                                 ...
# 1045  [Programming, Pair Programming, JavaScript, Le...
# 1046  [Programming, Codingbootcamp, Women In Tech, T...
# 1047   [Angular, Hip Hop, Code, Coding, Codingbootcamp]
# 1048  [Coding, Learning To Code, Codingbootcamp, Car...
# 1049  [JavaScript, Learning To Code, Coding, Codingb...
# 1050         [Interview, Codingbootcamp, Career Change]
# 1051  [Internships, Coding, Codingbootcamp, JavaScri...
# 1052  [Codingbootcamp, Success Stories, Learntocode,...
# 1053   [Humor, Ironhack, Coding, Miami, Codingbootcamp]
# 1054  [Coding, Learning To Code, Self Improvement, C...
# 1055  [Programming, Women In Tech, Coding, Software ...
# 1056  [Coding, Codingbootcamp, JavaScript, Community...
# 1057  [Christianity, Internships, Coding, Codingboot...
# 1058   [Coding, Codingbootcamp, Hip Hop, Code, Orlando]
# 1059  [JavaScript, This, Codingbootcamp, Binding, Tech]
# 1060  [Ios Development, Codingbootcamp, Learning To ...
# 1061  [JavaScript, Javascript Tips, Javascript Devel...
# 1062  [Git, Today I Learned, Programming, Coding, Co...
# 1063  [Chingu, Freecodecamp, React, Codingbootcamp, ...
# 1064  [Swift 4, Swift Programming, Mobile App Develo...
# 1065  [Tech, Coding, Codingbootcamp, Programming, So...
# 1066       [Programming, Codingbootcamp, Kittens, Blog]
# 1060  https://medium.com/@FranziskaLuzia/where-to-st...
# 1061  https://medium.com/@seancsutton1/an-incredibly...
# 1062  https://medium.com/@blakeschlin/my-first-til-9...
# 1063  https://medium.com/chingu/chingu-weekly-vol-61...
# 1064  https://medium.com/@createwithcodes/the-differ...
# 1065  https://medium.com/@sbogucki12/bootstrap-is-my...
# 1066  https://medium.com/@katedoesdev/how-coding-boo...
# 1067  https://medium.com/@swkane/hello-world-ff5b2af...
# 1068  https://hackernoon.com/dev-bootcamp-closes-par...
# 1069  https://medium.com/@rithmschool/student-interv...
# 1070  https://medium.com/@adt6261/cs-100-5-sorting-p...
# 1071  https://medium.com/datadriveninvestor/3-weeks-...
# 1072  https://medium.com/@ahdorneles/vai-come%C3%A7a...
# 1073  https://medium.com/@emilyldeans/something-that...
# 1074  https://medium.com/@emilyldeans/saturdays-a-cb...
#
# [1075 rows x 8 columns]

# %%
#Convert to csv so I don't have to run the collection function again - it takes FOREVER
Codingbootcamp_info.to_csv("codingbootcamp_articles_info.csv")

# %%
#see frequency of different tags
Codingbootcamp_info["tags"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-733cc1f1234f> in <module>()
#       1 #see frequency of different tags
# ----> 2 Codingbootcamp_info["tags"].value_counts()
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/pandas/core/base.py in value_counts(self, normalize, sort, ascending, bins, dropna)
#     928         from pandas.core.algorithms import value_counts
#     929         result = value_counts(self, sort=sort, ascending=ascending,
# --> 930                               normalize=normalize, bins=bins, dropna=dropna)
#     931         return result
#     932
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/pandas/core/algorithms.py in value_counts(values, sort, ascending, normalize, bins, dropna)
#     633
#     634         else:
# --> 635             keys, counts = _value_counts_arraylike(values, dropna)
#     636
#     637             if not isinstance(keys, Index):
#
# /Users/shalini/anaconda/lib/python3.6/site-packages/pandas/core/algorithms.py in _value_counts_arraylike(values, dropna)
#     678         # TODO: handle uint8
#     679         f = getattr(htable, "value_count_{dtype}".format(dtype=ndtype))
# --> 680         keys, counts = f(values, dropna)
#     681
#     682         mask = isnull(values)
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object (pandas/_libs/hashtable.c:28955)()
#
# pandas/_libs/hashtable_func_helper.pxi in pandas._libs.hashtable.value_count_object (pandas/_libs/hashtable.c:28704)()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# We cannot get the value_counts of a list object so we need to get a little creative in order to get the value_counts of the elements in the list (tag column).

# %%
newdf = Codingbootcamp_info["tags"].apply(pd.Series).stack().reset_index(level=1, drop=True).to_frame('tags')
newdf["tags"].value_counts()
# Out:
# Codingbootcamp          1002
# Coding                   476
# Programming              412
# Web Development          207
# JavaScript               177
# Learning To Code         101
# Education                 90
# Women In Tech             74
# Software Development      60
# Tech                      49
# Technology                49
# Ruby                      48
# Coding Bootcamps          42
# The Iron Yard             41
# Startup                   36
# Career Change             35
# Ruby on Rails             35
# Internships               34
# Bootcamp                  32
# Freecodecamp              31
# Learn To Code             30
# Coding Bootcamp           29
# Ecole 42                  29
# Code Newbie               28
# Code                      27
# React                     26
# Chingu                    24
# Life Lessons              24
# Women Who Code            22
# Computer Science          21
#                         ...
# Meaningful Work            1
# Girls                      1
# Adversity                  1
# Frustration                1
# Quality                    1
# Medium Japan               1
# Dont Be Desperate          1
# Anthony Delgado            1
# Copywriting                1
# Computers                  1
# Leadership                 1
# Management                 1
# Sci Fi Tech                1
# Digital Nomads             1
# Swimming                   1
# Single Moms                1
# Web App Development        1
# Confidence                 1
# Books                      1
# Zoo                        1
# Codingislife               1
# Kittens                    1
# Vscode                     1
# Codeproject                1
# Impact                     1
# Satire                     1
# Fullstack Founders         1
# PHP                        1
# Budget                     1
# Data Analytics             1
# Name: tags, Length: 724, dtype: int64

# %% [markdown]
# I will play around with this more later, but for now let's look at gender of the names! We need more data than just the author name, in order to tell if they are male or female, so I am going to import the babynames data from the SSN website which may have information that is useful.

# %%
import urllib.request
import os.path

data_url = "https://www.ssa.gov/oact/babynames/names.zip"
local_filename = "babynames.zip"
if not os.path.exists(local_filename): # if the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

# %% [markdown]
# The data is organized into separate files in the format `yobYYYY.txt` with each file containing the `name`, `sex`, and `count` of babies registered in that year. Now we load the data directly into Python without unzipping in order to increase efficiency.

# %%
import zipfile
babynames = [] 
with zipfile.ZipFile(local_filename, "r") as zf:
    data_files = [f for f in zf.filelist if f.filename[-3:] == "txt"]
    def extract_year_from_filename(fn):
        return int(fn[3:7])
    for f in data_files:
        year = extract_year_from_filename(f.filename)
        with zf.open(f) as fp:
            df = pd.read_csv(fp, names=["Name", "Sex", "Count"])
            df["Year"] = year
            babynames.append(df)
babynames = pd.concat(babynames)

# %%
babynames.head()
# Out:
#         Name Sex  Count  Year
# 0       Mary   F   7065  1880
# 1       Anna   F   2604  1880
# 2       Emma   F   2003  1880
# 3  Elizabeth   F   1939  1880
# 4     Minnie   F   1746  1880

# %% [markdown]
# Yay now we have a babynames dataset to use!

# %% [markdown]
# Let's start off my making the names in the babynames dataset and our own data frame, lowercase (for standardization purposes so we can easily find patterns and matches). I'll create a new column for the lowercase name so we don't lose the original data.

# %%
babynames["LName"] = babynames["Name"].str.lower()
babynames.head()
# Out:
#         Name Sex  Count  Year Lowercase Name  prob_female      LName
# 0       Mary   F   7065  1880           mary          NaN       mary
# 1       Anna   F   2604  1880           anna          NaN       anna
# 2       Emma   F   2003  1880           emma          NaN       emma
# 3  Elizabeth   F   1939  1880      elizabeth          NaN  elizabeth
# 4     Minnie   F   1746  1880         minnie          NaN     minnie

# %%
Codingbootcamp_info["lowercase author"] = Codingbootcamp_info["author"].str.lower()
Codingbootcamp_info.head()
# Out:
#                   author                                         author_bio  \
# 0          Kalen Hammann                                               None
# 1             Mike Brave  I make things with design and code. Here's to ...
# 2        Irsan Sebastian                                               None
# 3             KeepCoding  We create the best learning experience for Ful...
# 4  Sabio Coding Bootcamp  Lead by the most senior coding bootcamp staff ...
#
#                                                title                 date  \
# 0  A New Beginning, Part 22 – Kalen Hammann – Medium  2017-08-07 12:51:18
# 1  Why I’m Taking a Chance on 42 – Mike Brave – M...  2018-08-06 07:04:49
# 2  Let’s start a journey ! – Irsan Sebastian – Me...  2016-11-05 14:19:30
# 3  KeepCoding Bootcamp KickOff Event – KeepCoding...  2017-05-16 12:38:42
# 4  Coding Bootcamp Student Tells All – Sabio Codi...  2018-09-14 07:33:30
#
#   publisher                                               text  \
# 0    medium  A New Beginning, Part 22 W E E K 22: Already?!...
# 1    medium  Why I’m Taking a Chance on 42 Edit: This is pa...
# 2    medium  Let’s start a journey ! Nama gue Irsan, gue se...
# 3    medium  Keep Coding Bootcamp Kick Off Event2017 Mobile...
# 4   wesabio  Coding Bootcamp Student Tells All Sabio coding...
#
#                                                 tags  \
# 0  [Web Development, Codingbootcamp, Code Review,...
# 1       [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2  [Story, My Life, Codingbootcamp, Coding, Startup]
# 3  [Programming, Codingbootcamp, Web Development,...
# 4                 [Veterans In Tech, Codingbootcamp]
#
#                                                  url       lowercase author
# 0  https://medium.com/@kalen7/a-surprising-career...          kalen hammann
# 1  https://medium.com/@themichaelbrave/why-im-tak...             mike brave
# 2  https://medium.com/@irsansebastian/lets-start-...        irsan sebastian
# 3  https://medium.com/@KeepCoding_/keepcoding-boo...             keepcoding
# 4  https://blog.sabio.la/coding-bootcamp-student-...  sabio coding bootcamp

# %% [markdown]
# See the total number of babies with each name broken down by sex.

# %%
sex_counts = pd.pivot_table(babynames, index='LName', columns='Sex', values='Count',
                            aggfunc='sum', fill_value=0., margins=True)
sex_counts.head()
# Out:
# Sex           F      M    All
# LName
# aaban       0.0  107.0  107.0
# aabha      35.0    0.0   35.0
# aabid       0.0   10.0   10.0
# aabir       0.0    5.0    5.0
# aabriella  32.0    0.0   32.0

# %% [markdown]
# Calculate the probability a name is female:

# %%
prob_female = sex_counts['F'] / sex_counts['All'] 
prob_female.head(10)
# Out:
# LName
# aaban        0.000000
# aabha        1.000000
# aabid        0.000000
# aabir        0.000000
# aabriella    1.000000
# aada         1.000000
# aadam        0.000000
# aadan        0.000000
# aadarsh      0.000000
# aaden        0.001073
# dtype: float64

# %%
prob_female["shalini"]
# Out:
# 1.0

# %% [markdown]
# Similarly, we can calculate the probability a name is male:

# %%
prob_male = sex_counts['M'] / sex_counts['All'] 
prob_male.head(10)
# Out:
# LName
# aaban        1.000000
# aabha        0.000000
# aabid        1.000000
# aabir        1.000000
# aabriella    0.000000
# aada         0.000000
# aadam        1.000000
# aadan        1.000000
# aadarsh      1.000000
# aaden        0.998927
# dtype: float64

# %% [markdown]
# I will define a function to return the most likely `Sex` for a name. If there is an exact tie, the function returns Male. If the name does not appear in the social security dataset, return Unknown.

# %%
def sex_from_name(name):
    lower_name = name.lower()
    if lower_name in prob_female.index:
        return 'F' if prob_female[lower_name] > 0.5 else 'M'
    else:
        return "Unknown"

def prob_sex_from_name(name, sex):
#     lower_name = name.lower()
    if sex == "F":
        return prob_female[lower_name]
    elif sex == 'M':
        return prob_male[lower_name]
    else:
        return "Unknown"

# %%
shalini_sex = sex_from_name('shalini')
shalini_sex
# Out:
# 'F'

# %%
sex_from_name('aaden')
# Out:
# 'M'

# %%
prob_sex_from_name('shalini', shalini_sex)
# Out:
# 1.0

# %% [markdown]
# Now let me find a way to apply this function to our own dataframe in order to predict the gender of the different authors.
# Next steps:
# * Need to get the first name of the author
# * Filter out any companies/orgs that may be in the author column
# * Apply sex_from_name function to names in the bootcamp dataframe
# * Have a confidence interval (if possible) or different measure of how sure we are about the given gender
# * Create different dataframes with org data and personal data (as publisher/author)

# %% [markdown]
# Let's go back to our dataframe and filter out anything that may be companies or organizations

# %%
Codingbootcamp_info.head()
# Out:
#                   author                                         author_bio  \
# 0          Kalen Hammann                                               None
# 1             Mike Brave  I make things with design and code. Here's to ...
# 2        Irsan Sebastian                                               None
# 3             KeepCoding  We create the best learning experience for Ful...
# 4  Sabio Coding Bootcamp  Lead by the most senior coding bootcamp staff ...
#
#                                                title                 date  \
# 0  A New Beginning, Part 22 – Kalen Hammann – Medium  2017-08-07 12:51:18
# 1  Why I’m Taking a Chance on 42 – Mike Brave – M...  2018-08-06 07:04:49
# 2  Let’s start a journey ! – Irsan Sebastian – Me...  2016-11-05 14:19:30
# 3  KeepCoding Bootcamp KickOff Event – KeepCoding...  2017-05-16 12:38:42
# 4  Coding Bootcamp Student Tells All – Sabio Codi...  2018-09-14 07:33:30
#
#   publisher                                               text  \
# 0    medium  A New Beginning, Part 22 W E E K 22: Already?!...
# 1    medium  Why I’m Taking a Chance on 42 Edit: This is pa...
# 2    medium  Let’s start a journey ! Nama gue Irsan, gue se...
# 3    medium  Keep Coding Bootcamp Kick Off Event2017 Mobile...
# 4   wesabio  Coding Bootcamp Student Tells All Sabio coding...
#
#                                                 tags  \
# 0  [Web Development, Codingbootcamp, Code Review,...
# 1       [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2  [Story, My Life, Codingbootcamp, Coding, Startup]
# 3  [Programming, Codingbootcamp, Web Development,...
# 4                 [Veterans In Tech, Codingbootcamp]
#
#                                                  url       lowercase author
# 0  https://medium.com/@kalen7/a-surprising-career...          kalen hammann
# 1  https://medium.com/@themichaelbrave/why-im-tak...             mike brave
# 2  https://medium.com/@irsansebastian/lets-start-...        irsan sebastian
# 3  https://medium.com/@KeepCoding_/keepcoding-boo...             keepcoding
# 4  https://blog.sabio.la/coding-bootcamp-student-...  sabio coding bootcamp

# %% [markdown]
# A list of the things to filter out: when publisher is wesabio, code.likeagirl.io, makersacademy, hackernoon, fuerzamuktek, codeburst, ubiqum, fundapps, itnext.io, propulsioncodingacademy, PrototyprIO.

# %%
orgs = ["wesabio", "code.likeagirl.io", "makersacademy", "hackernoon", "fuerzamuktek", "codeburst", "ubiqum", "fundapps", "itnext.io", "propulsioncodingacademy", "PrototyprIO"]
new_codingdf = Codingbootcamp_info[~Codingbootcamp_info["publisher"].isin(orgs)]
orgs_df = Codingbootcamp_info[Codingbootcamp_info["publisher"].isin(orgs)]
new_codingdf
# Out:
#                           author  \
# 0                  Kalen Hammann
# 1                     Mike Brave
# 2                Irsan Sebastian
# 3                     KeepCoding
# 5                     Mike Brave
# 6               Better Developer
# 7                     adam tropp
# 8                 Verity Honebon
# 9               Manchester Codes
# 10               Code Collective
# 12                    Ari Kramer
# 13                   Erin Levine
# 14                       conshus
# 15                    Mike Brave
# 16                   Jacob Moore
# 18                     Jeff Wong
# 19                   Kyle Thayer
# 20                    Max Berger
# 21                Robert Furtado
# 22               Natasha Robarge
# 23                           이상훈
# 24               Accelerate Tech
# 25                      Abi Noda
# 26                    adam tropp
# 27                    Kait Sykes
# 28                  Leibel Hecht
# 29                    Mike Brave
# 30               Joseph Cardillo
# 31    Patricia Eunice Miraflores
# 33              Kamrin Klauschie
# ...                          ...
# 1041                     Yan Fan
# 1042               Tyrell Gordon
# 1043                Rithm School
# 1044              Pierre Hersant
# 1045             Connor Kirkwood
# 1047                     conshus
# 1048                  King Nimmo
# 1049               Mauro Gestoso
# 1050                   Dex Mills
# 1051            chibueze ukaegbu
# 1053            Giannini Charles
# 1054                 David Clark
# 1056                Scott Bowman
# 1057            chibueze ukaegbu
# 1058                     conshus
# 1059                       J.Lim
# 1060             Franziska Luzia
# 1061                 Sean Sutton
# 1062                Blake Schlin
# 1063                Chance Taken
# 1064                Swift Snacks
# 1065               Steve Bogucki
# 1066                Kate Walters
# 1067                    Sam Kane
# 1069                Rithm School
# 1070                  adam tropp
# 1071               Jessica Alves
# 1072      Adriana Höher Dorneles
# 1073                 Emily Deans
# 1074                 Emily Deans
#
#                                              author_bio  \
# 0                                                  None
# 1     I make things with design and code. Here's to ...
# 2                                                  None
# 3     We create the best learning experience for Ful...
# 5     I make things with design and code. Here's to ...
# 6     Sharing my experience in what it takes to beco...
# 7                                                  None
# 8                                                  None
# 9                                     https://mcr.codes
# 10    Exposing the world to code. Questions/Feedback...
# 12                                                 None
# 13    Pretending to be an adult. Discussin' the ebb ...
# 14    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 15    I make things with design and code. Here's to ...
# 16                                                 None
# 18                                        Web developer
# 19    I am a PhD student studying programming, cultu...
# 20                                                 None
# 21                          Founder of CourseCompare.ca
# 22    Software Consultant | Tech Enthusiast | Fitnes...
# 23                                                 None
# 24                                                 None
# 25    Independent developer and founder of http://pu...
# 26                                                 None
# 27    Web developer via @hackeryou. Slytherin. Popco...
# 28    I’m Leibel. I’m transitioning from Talmud to T...
# 29    I make things with design and code. Here's to ...
# 30    Curious about everything. Literature, Fiction,...
# 31                                                 None
# 33          Be the hustle you wish to see in the world.
# ...                                                 ...
# 1041  Co-Founder & CTO of Code Chrysalis, a coding b...
# 1042                                               None
# 1043  18 week program on #JavaScript #ReactJS and #P...
# 1044                       I do stuff behind a computer
# 1045                                               None
# 1047  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1048  We are Vanessa Nimmo and Celia King. We are ma...
# 1049  Carbon based life form. Angry cyclist. JavaScr...
# 1050                                       dexmills.com
# 1051                                               None
# 1053                                               None
# 1054  Mindfulness | Humans | Animals | Earth | Codin...
# 1056                                               None
# 1057                                               None
# 1058  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
#
# 1          [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2     [Story, My Life, Codingbootcamp, Coding, Startup]
# 3     [Programming, Codingbootcamp, Web Development,...
# 5     [Life Lessons, Ecole 42, Education, Codingboot...
# 6     [Software Development, Learning To Code, Learn...
# 7       [Programming, Codingbootcamp, Computer Science]
# 8     [Programming, Coding, Codingbootcamp, Collabor...
# 9     [Programming, Manchester Codes, Manchester, Co...
# 10    [Programming, Coding, Codingbootcamp, Code, Ed...
# 12       [Coding, Software Development, Codingbootcamp]
# 13    [JavaScript, Web Development, Coding, Codingbo...
# 14    [Reactjs, Firebase, Coding, Codingbootcamp, Hi...
# 15     [Art, Ecole 42, Code, Education, Codingbootcamp]
# 16                         [JavaScript, Codingbootcamp]
# 18    [Programming, Career Change, Software Developm...
# 19    [Programming, Computer Science, Codingbootcamp...
# 20    [Productivity, Coding, Hack Reactor, Codingboo...
# 21    [Programming, Digital Marketing, Codingbootcam...
# 22    [Programming, College, Codingbootcamp, Coding,...
# 23    [Codingbootcamp, JavaScript, Function, Front E...
# 24    [Web Development, Programming, Codingbootcamp,...
# 25    [Programming, Codingbootcamp, Web Development,...
# 26    [JavaScript, Codingbootcamp, Programming, Comp...
# 27    [Web Development, Wireframe, Coding, Coding Bo...
# 28    [Data Science, Data, Codingbootcamp, Coding, W...
# 29    [Life Lessons, Ecole 42, Education, Codingboot...
# 30                                     [Codingbootcamp]
# 31    [Codingbootcamp, Philippines, Startup, Front E...
# 33    [Programming, Education, Software, Coding, Cod...
# ...                                                 ...
# 1041  [JavaScript, Coding, Coding Bootcamp, Tokyo, J...
# 1042           [Anime, Codingbootcamp, Flatiron School]
# 1043  [Education, Coding, Codingbootcamp, JavaScript...
# 1044    [Programming, Bootcamp, Coding, Codingbootcamp]
# 1045  [Programming, Pair Programming, JavaScript, Le...
# 1047   [Angular, Hip Hop, Code, Coding, Codingbootcamp]
# 1048  [Coding, Learning To Code, Codingbootcamp, Car...
# 1049  [JavaScript, Learning To Code, Coding, Codingb...
# 1050         [Interview, Codingbootcamp, Career Change]
# 1051  [Internships, Coding, Codingbootcamp, JavaScri...
# 1053   [Humor, Ironhack, Coding, Miami, Codingbootcamp]
# 1054  [Coding, Learning To Code, Self Improvement, C...
# 1056  [Coding, Codingbootcamp, JavaScript, Community...
# 1057  [Christianity, Internships, Coding, Codingboot...
# 1058   [Coding, Codingbootcamp, Hip Hop, Code, Orlando]
# 1059  [JavaScript, This, Codingbootcamp, Binding, Tech]
# 1060  [Ios Development, Codingbootcamp, Learning To ...
# 1061  [JavaScript, Javascript Tips, Javascript Devel...
# 1062  [Git, Today I Learned, Programming, Coding, Co...
# 1063  [Chingu, Freecodecamp, React, Codingbootcamp, ...
# 1064  [Swift 4, Swift Programming, Mobile App Develo...
# 1065  [Tech, Coding, Codingbootcamp, Programming, So...
# 1066       [Programming, Codingbootcamp, Kittens, Blog]
# 1067  [Programming, Coding, Codingbootcamp, The Iron...
# 1069  [Programming, Web Development, Job Hunting, Co...
# 1063  https://medium.com/chingu/chingu-weekly-vol-61...
# 1064  https://medium.com/@createwithcodes/the-differ...
# 1065  https://medium.com/@sbogucki12/bootstrap-is-my...
# 1066  https://medium.com/@katedoesdev/how-coding-boo...
# 1067  https://medium.com/@swkane/hello-world-ff5b2af...
# 1069  https://medium.com/@rithmschool/student-interv...
# 1070  https://medium.com/@adt6261/cs-100-5-sorting-p...
# 1071  https://medium.com/datadriveninvestor/3-weeks-...
# 1072  https://medium.com/@ahdorneles/vai-come%C3%A7a...
# 1073  https://medium.com/@emilyldeans/something-that...
# 1074  https://medium.com/@emilyldeans/saturdays-a-cb...
#
#                 lowercase author
# 0                  kalen hammann
# 1                     mike brave
# 2                irsan sebastian
# 3                     keepcoding
# 5                     mike brave
# 6               better developer
# 7                     adam tropp
# 8                 verity honebon
# 9               manchester codes
# 10               code collective
# 12                    ari kramer
# 13                   erin levine
# 14                       conshus
# 15                    mike brave
# 16                   jacob moore
# 18                     jeff wong
# 19                   kyle thayer
# 20                    max berger
# 21                robert furtado
# 22               natasha robarge
# 23                           이상훈
# 24               accelerate tech
# 25                      abi noda
# 26                    adam tropp
# 27                    kait sykes
# 28                  leibel hecht
# 29                    mike brave
# 30               joseph cardillo
# 31    patricia eunice miraflores
# 33              kamrin klauschie
# ...                          ...
# 1041                     yan fan
# 1042               tyrell gordon
# 1043                rithm school
# 1044              pierre hersant
# 1045             connor kirkwood
# 1047                     conshus
# 1048                  king nimmo
# 1049               mauro gestoso
# 1050                   dex mills
# 1051            chibueze ukaegbu
# 1053            giannini charles
# 1054                 david clark
# 1056                scott bowman
# 1057            chibueze ukaegbu
# 1058                     conshus
# 1059                       j.lim
# 1060             franziska luzia
# 1061                 sean sutton
# 1062                blake schlin
# 1063                chance taken
# 1064                swift snacks
# 1065               steve bogucki
# 1066                kate walters
# 1067                    sam kane
# 1069                rithm school
# 1070                  adam tropp
# 1071               jessica alves
# 1072      adriana höher dorneles
# 1073                 emily deans
# 1074                 emily deans
#
# [986 rows x 9 columns]

# %% [markdown]
# From a manual look at the filtered dataframe, I am also going to filter out rows that have author KeepCoding, Better Developer, Manchester Codes, Code Collective, Accelerate Tech, Rithm School.

# %%
more_orgs = ["KeepCoding", "Better Developer", "Manchester Codes", "Code Collective", "Accelerate Tech", "Rithm School"]
new_codingdf = new_codingdf[~new_codingdf["author"].isin(more_orgs)]
new_codingdf
# Out:
#                           author  \
# 0                  Kalen Hammann
# 1                     Mike Brave
# 2                Irsan Sebastian
# 5                     Mike Brave
# 7                     adam tropp
# 8                 Verity Honebon
# 12                    Ari Kramer
# 13                   Erin Levine
# 14                       conshus
# 15                    Mike Brave
# 16                   Jacob Moore
# 18                     Jeff Wong
# 19                   Kyle Thayer
# 20                    Max Berger
# 21                Robert Furtado
# 22               Natasha Robarge
# 23                           이상훈
# 25                      Abi Noda
# 26                    adam tropp
# 27                    Kait Sykes
# 28                  Leibel Hecht
# 29                    Mike Brave
# 30               Joseph Cardillo
# 31    Patricia Eunice Miraflores
# 33              Kamrin Klauschie
# 34                    D Saunders
# 35                  Chance Taken
# 36                    Riza Fahmi
# 37                   Emily Deans
# 38            Marshall Pritchett
# ...                          ...
# 1039              Krystyna Ewing
# 1040                 Vikash Hart
# 1041                     Yan Fan
# 1042               Tyrell Gordon
# 1044              Pierre Hersant
# 1045             Connor Kirkwood
# 1047                     conshus
# 1048                  King Nimmo
# 1049               Mauro Gestoso
# 1050                   Dex Mills
# 1051            chibueze ukaegbu
# 1053            Giannini Charles
# 1054                 David Clark
# 1056                Scott Bowman
# 1057            chibueze ukaegbu
# 1058                     conshus
# 1059                       J.Lim
# 1060             Franziska Luzia
# 1061                 Sean Sutton
# 1062                Blake Schlin
# 1063                Chance Taken
# 1064                Swift Snacks
# 1065               Steve Bogucki
# 1066                Kate Walters
# 1067                    Sam Kane
# 1070                  adam tropp
# 1071               Jessica Alves
# 1072      Adriana Höher Dorneles
# 1073                 Emily Deans
# 1074                 Emily Deans
#
#                                              author_bio  \
# 0                                                  None
# 1     I make things with design and code. Here's to ...
# 2                                                  None
# 5     I make things with design and code. Here's to ...
# 7                                                  None
# 8                                                  None
# 12                                                 None
# 13    Pretending to be an adult. Discussin' the ebb ...
# 14    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 15    I make things with design and code. Here's to ...
# 16                                                 None
# 18                                        Web developer
# 19    I am a PhD student studying programming, cultu...
# 20                                                 None
# 21                          Founder of CourseCompare.ca
# 22    Software Consultant | Tech Enthusiast | Fitnes...
# 23                                                 None
# 25    Independent developer and founder of http://pu...
# 26                                                 None
# 27    Web developer via @hackeryou. Slytherin. Popco...
# 28    I’m Leibel. I’m transitioning from Talmud to T...
# 29    I make things with design and code. Here's to ...
# 30    Curious about everything. Literature, Fiction,...
# 31                                                 None
# 33          Be the hustle you wish to see in the world.
# 34         Excited about Big data + education + economy
# 35          Facilitator @ Chingu. Apply here: chingu.io
# 36    Co-founder, Curriculum Director at Hacktiv8.co...
# 37    Washington, D.C.-based web developer. Former c...
# 38                                                 None
# ...                                                 ...
# 1039  Developer | Comic Artist | Veteran | Member of...
# 1040  Hey everyone, I'm an iOS developer and pretty ...
# 1041  Co-Founder & CTO of Code Chrysalis, a coding b...
# 1042                                               None
# 1044                       I do stuff behind a computer
# 1045                                               None
# 1047  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1048  We are Vanessa Nimmo and Celia King. We are ma...
# 1049  Carbon based life form. Angry cyclist. JavaScr...
# 1050                                       dexmills.com
# 1051                                               None
# 1053                                               None
# 1054  Mindfulness | Humans | Animals | Earth | Codin...
# 1056                                               None
# 1057                                               None
# 1058  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 1059  Learning JavaScript, Vue.js, Sass, Python, Dja...
# 1060        Digitalizing Fashion www.franziskaluzia.com
# 1061                                               None
# 1062                                               None
# 1063        Facilitator @ Chingu. Apply here: chingu.io
# 1064                                               None
# 1065  Recursively looping through toRun and toCode. ...
# 1066                                               None
# 1067  Full Stack Development Student at The Iron Yar...
# 1070                                               None
# 1071  Brazilian woman living in Sydney. Changing car...
# 1072  A Brazilian economist/accountant/developer tha...
# 27      medium  6 Tips for Wireframing before Coding What to d...
# 28      medium  Weather Mood Booster App. Yay! I made an app 🤓...
# 29      medium  42 Piscine Day 18 — (13) Edit: This is part of...
# 30      medium  Yesterday morning I spent a few hours working ...
# 31      medium  Founders of twenty-million dollar start-up off...
# 33      medium  How To Choose a Bootcamp Like a Bootcamp Emplo...
# 34      medium  It’s 6:15pm, we’ve been here since 8:30, and t...
# 35      medium  Chingu Weekly Vol. 56 My goodness! So many peo...
# 36      medium  Kenapa Edukasi Yang Bagus Itu Tidak Murah Harg...
# 37      medium  Something to Tell You It’s the Sunday afternoo...
# 38      medium  Path to Programmer: Chapter 1 Two years. It to...
# ...        ...                                                ...
# 1039    medium  Learning To Code: The Seven Kerfuffles Of Codi...
# 1040    medium  My Journey to Becoming “ Kash” the i O S Dev. ...
# 1041    medium  Why Java Script?“any application that can be w...
# 1042    medium  Be More Like Goku (a flatiron experience) Alri...
# 1044    medium  One year of web development after a bootcamp T...
# 1045    medium  The Three Pairs of Pair Programming Pair Progr...
# 1047    medium  Day 81 / Early to Riseliner notes: Professiona...
# 1048    medium  Transition into Tech Weekend napping after the...
# 1049    medium  Avoid Losing Your Sanity Working with Dates in...
# 1050    medium  Interviews, and slacking like a champ Its been...
# 1051    medium  Learn Factory Internship: Day 24 ( May 31, 201...
# 1053    medium  Project 1: Conquered On Friday, me and my team...
# 1054    medium  My Adventures into the Desolate Wasteland of S...
# 1056    medium  A Simple Solution to the Failure of Coding Boo...
# 1057    medium  Learn Factory Internship: Day 17 ( May 22, 201...
# 1058    medium  Day 45 - I'm so excitedliner notes: Yesterday ...
# 1059    medium  Java Script “ This” — Advanced J L’s Coding Bo...
# 1060    medium  Where to start Learning to Code Where to start...
# 1061    medium  An Incredibly Simple, Basic, Bare-bones Explan...
# 1062    medium  my first T. I. L At first I didn’t get why I n...
# 1063    medium  Chingu Weekly Vol. 61 — A Chingu just publishe...
# 1064    medium  The difference between Constants and variables...
# 1065    medium  Bootstrap is My New Buddy. Day Three at Comput...
# 1066    medium  How Coding Bootcamp Helped Save Me I started t...
# 1067    medium  Hello, World! My Path to a Coding Bootcamp Twe...
# 1070    medium  C S 100. 5: Sorting Part 2 Before we begin, I ...
# 1071    medium  3 weeks of coding bootcamp, how I feel…and why...
# 1072    medium  Vai começar… Sou formada em Economia. Até hoje...
# 1073    medium  Something that broke my brain A thing I’ve com...
# 1074    medium  Saturday’s a… There was a time in my life when...
#
#                                                    tags  \
# 0     [Web Development, Codingbootcamp, Code Review,...
# 1          [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2     [Story, My Life, Codingbootcamp, Coding, Startup]
# 5     [Life Lessons, Ecole 42, Education, Codingboot...
# 7       [Programming, Codingbootcamp, Computer Science]
# 8     [Programming, Coding, Codingbootcamp, Collabor...
# 12       [Coding, Software Development, Codingbootcamp]
# 13    [JavaScript, Web Development, Coding, Codingbo...
# 14    [Reactjs, Firebase, Coding, Codingbootcamp, Hi...
# 15     [Art, Ecole 42, Code, Education, Codingbootcamp]
# 16                         [JavaScript, Codingbootcamp]
# 18    [Programming, Career Change, Software Developm...
# 19    [Programming, Computer Science, Codingbootcamp...
# 20    [Productivity, Coding, Hack Reactor, Codingboo...
# 21    [Programming, Digital Marketing, Codingbootcam...
# 22    [Programming, College, Codingbootcamp, Coding,...
# 23    [Codingbootcamp, JavaScript, Function, Front E...
# 25    [Programming, Codingbootcamp, Web Development,...
# 26    [JavaScript, Codingbootcamp, Programming, Comp...
# 27    [Web Development, Wireframe, Coding, Coding Bo...
# 28    [Data Science, Data, Codingbootcamp, Coding, W...
# 29    [Life Lessons, Ecole 42, Education, Codingboot...
# 30                                     [Codingbootcamp]
# 31    [Codingbootcamp, Philippines, Startup, Front E...
# 33    [Programming, Education, Software, Coding, Cod...
# 34    [Machine Learning, Codingbootcamp, Education, ...
# 35    [Web Development, Chingu, Freecodecamp, Coding...
# 36    [Education, Coding Bootcamp, Publishing, Buku,...
# 37    [Web Development, Codingbootcamp, Women Who Co...
# 38    [Web Development, Nursing, Programming, Coding...
# ...                                                 ...
# 1039  [Programming, Learning To Code, Kerfuffle, Cod...
# 1040  [Programming, Developer, iOS, Swift, Codingboo...
# 1041  [JavaScript, Coding, Coding Bootcamp, Tokyo, J...
# 1042           [Anime, Codingbootcamp, Flatiron School]
# 1044    [Programming, Bootcamp, Coding, Codingbootcamp]
# 1045  [Programming, Pair Programming, JavaScript, Le...
# 1047   [Angular, Hip Hop, Code, Coding, Codingbootcamp]
# 1048  [Coding, Learning To Code, Codingbootcamp, Car...
# 1049  [JavaScript, Learning To Code, Coding, Codingb...
# 1050         [Interview, Codingbootcamp, Career Change]
# 1051  [Internships, Coding, Codingbootcamp, JavaScri...
# 1053   [Humor, Ironhack, Coding, Miami, Codingbootcamp]
# 1054  [Coding, Learning To Code, Self Improvement, C...
# 1056  [Coding, Codingbootcamp, JavaScript, Community...
# 1057  [Christianity, Internships, Coding, Codingboot...
# 1058   [Coding, Codingbootcamp, Hip Hop, Code, Orlando]
# 1059  [JavaScript, This, Codingbootcamp, Binding, Tech]
# 1060  [Ios Development, Codingbootcamp, Learning To ...
# 1061  [JavaScript, Javascript Tips, Javascript Devel...
# 1062  [Git, Today I Learned, Programming, Coding, Co...
# 1063  [Chingu, Freecodecamp, React, Codingbootcamp, ...
# 1064  [Swift 4, Swift Programming, Mobile App Develo...
# 1065  [Tech, Coding, Codingbootcamp, Programming, So...
# 1066       [Programming, Codingbootcamp, Kittens, Blog]
# 1067  [Programming, Coding, Codingbootcamp, The Iron...
# 1070  [JavaScript, Programming, Computer Science, Co...
# 1071  [Programming, Coding, Codingbootcamp, Women In...
# 1072  [Codingbootcamp, Coding, Girls In Tech, Career...
# 1073  [Life, Codingbootcamp, The Iron Yard, JavaScri...
# 1074  [Programming, Podcast, Women In Tech, Codingbo...
#
#                                                     url  \
# 0     https://medium.com/@kalen7/a-surprising-career...
# 1     https://medium.com/@themichaelbrave/why-im-tak...
# 1071  https://medium.com/datadriveninvestor/3-weeks-...
# 1072  https://medium.com/@ahdorneles/vai-come%C3%A7a...
# 1073  https://medium.com/@emilyldeans/something-that...
# 1074  https://medium.com/@emilyldeans/saturdays-a-cb...
#
#                 lowercase author
# 0                  kalen hammann
# 1                     mike brave
# 2                irsan sebastian
# 5                     mike brave
# 7                     adam tropp
# 8                 verity honebon
# 12                    ari kramer
# 13                   erin levine
# 14                       conshus
# 15                    mike brave
# 16                   jacob moore
# 18                     jeff wong
# 19                   kyle thayer
# 20                    max berger
# 21                robert furtado
# 22               natasha robarge
# 23                           이상훈
# 25                      abi noda
# 26                    adam tropp
# 27                    kait sykes
# 28                  leibel hecht
# 29                    mike brave
# 30               joseph cardillo
# 31    patricia eunice miraflores
# 33              kamrin klauschie
# 34                    d saunders
# 35                  chance taken
# 36                    riza fahmi
# 37                   emily deans
# 38            marshall pritchett
# ...                          ...
# 1039              krystyna ewing
# 1040                 vikash hart
# 1041                     yan fan
# 1042               tyrell gordon
# 1044              pierre hersant
# 1045             connor kirkwood
# 1047                     conshus
# 1048                  king nimmo
# 1049               mauro gestoso
# 1050                   dex mills
# 1051            chibueze ukaegbu
# 1053            giannini charles
# 1054                 david clark
# 1056                scott bowman
# 1057            chibueze ukaegbu
# 1058                     conshus
# 1059                       j.lim
# 1060             franziska luzia
# 1061                 sean sutton
# 1062                blake schlin
# 1063                chance taken
# 1064                swift snacks
# 1065               steve bogucki
# 1066                kate walters
# 1067                    sam kane
# 1070                  adam tropp
# 1071               jessica alves
# 1072      adriana höher dorneles
# 1073                 emily deans
# 1074                 emily deans
#
# [957 rows x 9 columns]

# %% [markdown]
# Now I need to get the first name of the author in "lowercase author" in order to put it through the gender function.

# %%
new_codingdf["first name"] = new_codingdf["lowercase author"].str.split(' ').str.get(0)
new_codingdf.head()
# Out:
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#             author                                         author_bio  \
# 0    Kalen Hammann                                               None
# 1       Mike Brave  I make things with design and code. Here's to ...
# 2  Irsan Sebastian                                               None
# 5       Mike Brave  I make things with design and code. Here's to ...
# 7       adam tropp                                               None
#
#                                                title                 date  \
# 0  A New Beginning, Part 22 – Kalen Hammann – Medium  2017-08-07 12:51:18
# 1  Why I’m Taking a Chance on 42 – Mike Brave – M...  2018-08-06 07:04:49
# 2  Let’s start a journey ! – Irsan Sebastian – Me...  2016-11-05 14:19:30
# 5     42 Piscine Day 11 — (08) – Mike Brave – Medium  2018-08-31 04:33:26
# 7       CS 100.3: Linked Lists – adam tropp – Medium  2018-05-16 21:39:10
#
#   publisher                                               text  \
# 0    medium  A New Beginning, Part 22 W E E K 22: Already?!...
# 1    medium  Why I’m Taking a Chance on 42 Edit: This is pa...
# 2    medium  Let’s start a journey ! Nama gue Irsan, gue se...
# 5    medium  42 Piscine Day 11 — (08) Edit: This is part of...
# 7    medium  C S 100. 3: Linked Lists Without further ado, ...
#
#                                                 tags  \
# 0  [Web Development, Codingbootcamp, Code Review,...
# 1       [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2  [Story, My Life, Codingbootcamp, Coding, Startup]
# 5  [Life Lessons, Ecole 42, Education, Codingboot...
# 7    [Programming, Codingbootcamp, Computer Science]
#
#                                                  url lowercase author  \
# 0  https://medium.com/@kalen7/a-surprising-career...    kalen hammann
# 1  https://medium.com/@themichaelbrave/why-im-tak...       mike brave
# 2  https://medium.com/@irsansebastian/lets-start-...  irsan sebastian
# 5  https://medium.com/@themichaelbrave/42-piscine...       mike brave
# 7  https://medium.com/@adt6261/cs-100-3-linked-li...       adam tropp
#
#   first name
# 0      kalen
# 1       mike
# 2      irsan
# 5       mike
# 7       adam

# %% [markdown]
# Now put it through the gender function

# %%
new_codingdf["gender"] = new_codingdf["first name"].apply(sex_from_name)
# Out:
# /Users/shalini/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new_codingdf.head()
# Out:
#             author                                         author_bio  \
# 0    Kalen Hammann                                               None
# 1       Mike Brave  I make things with design and code. Here's to ...
# 2  Irsan Sebastian                                               None
# 5       Mike Brave  I make things with design and code. Here's to ...
# 7       adam tropp                                               None
#
#                                                title                 date  \
# 0  A New Beginning, Part 22 – Kalen Hammann – Medium  2017-08-07 12:51:18
# 1  Why I’m Taking a Chance on 42 – Mike Brave – M...  2018-08-06 07:04:49
# 2  Let’s start a journey ! – Irsan Sebastian – Me...  2016-11-05 14:19:30
# 5     42 Piscine Day 11 — (08) – Mike Brave – Medium  2018-08-31 04:33:26
# 7       CS 100.3: Linked Lists – adam tropp – Medium  2018-05-16 21:39:10
#
#   publisher                                               text  \
# 0    medium  A New Beginning, Part 22 W E E K 22: Already?!...
# 1    medium  Why I’m Taking a Chance on 42 Edit: This is pa...
# 2    medium  Let’s start a journey ! Nama gue Irsan, gue se...
# 5    medium  42 Piscine Day 11 — (08) Edit: This is part of...
# 7    medium  C S 100. 3: Linked Lists Without further ado, ...
#
#                                                 tags  \
# 0  [Web Development, Codingbootcamp, Code Review,...
# 1       [Life Lessons, 42, Codingbootcamp, Ecole 42]
# 2  [Story, My Life, Codingbootcamp, Coding, Startup]
# 5  [Life Lessons, Ecole 42, Education, Codingboot...
# 7    [Programming, Codingbootcamp, Computer Science]
#
#                                                  url lowercase author  \
# 0  https://medium.com/@kalen7/a-surprising-career...    kalen hammann
# 1  https://medium.com/@themichaelbrave/why-im-tak...       mike brave
# 2  https://medium.com/@irsansebastian/lets-start-...  irsan sebastian
# 5  https://medium.com/@themichaelbrave/42-piscine...       mike brave
# 7  https://medium.com/@adt6261/cs-100-3-linked-li...       adam tropp
#
#   first name   gender
# 0      kalen        M
# 1       mike        M
# 2      irsan  Unknown
# 5       mike        M
# 7       adam        M

# %%
new_codingdf["gender"].value_counts()
# Out:
# M          499
# F          232
# Unknown    226
# Name: gender, dtype: int64

# %% [markdown]
# We have quite a few unknowns in our dataset (almost one fourth, so let's just take a look at these values)

# %%
new_codingdf[new_codingdf["gender"] == "Unknown"]
# Out:
#                               author  \
# 2                    Irsan Sebastian
# 14                           conshus
# 23                               이상훈
# 28                      Leibel Hecht
# 34                        D Saunders
# 43                        Develop Me
# 46                    Altcademy Team
# 47                           conshus
# 49                 Ilsmarie Presilia
# 51                          Horizons
# 54                              Bloc
# 56                         Anonymous
# 64                   Venturi's Voice
# 65                          SmartZoe
# 69                     Turing School
# 72                       App Academy
# 77                           conshus
# 78                              Eazi
# 83                        Develop Me
# 84                          Modestas
# 88                                 E
# 90                           conshus
# 105                             Bloc
# 123   Hindsight Technology Solutions
# 135                         CodeClan
# 144                     Leibel Hecht
# 146                         Horizons
# 150                         C Miller
# 154                     Hack Reactor
# 157                   irra wulandari
# ...                              ...
# 938                    Team Codebase
# 940                          conshus
# 942                          conshus
# 944                     Hack Reactor
# 948                          CeroUno
# 955                      L.J. Yockey
# 960                Fullstack Academy
# 961                         MG Ayoub
# 966                  Fanis Despoudis
# 968                      Jehoshuah K
# 976                            J.Lim
# 980                     Code Platoon
# 981                         Modestas
# 983                     Leibel Hecht
# 987                   Nakuya Bridget
# 988                  Björn Schmidtke
# 995                     Hack Reactor
# 1002                     L.J. Yockey
# 1015                         conshus
# 1019                     L.J. Yockey
# 1021                   ThirdEyeMedia
# 1024                Fredy-Edwin Esse
# 1025                     L.J. Yockey
# 1029                  Women Who Code
# 1034                     Coding Days
# 1037                        Modestas
# 1047                         conshus
# 1053                Giannini Charles
# 1058                         conshus
# 1059                           J.Lim
#
#                                              author_bio  \
# 2                                                  None
# 14    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 23                                                 None
# 28    I’m Leibel. I’m transitioning from Talmud to T...
# 34         Excited about Big data + education + economy
# 43    We are a talent and digital skills accelerator...
# 46                        The team behind Altcademy.com
# 47    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 49    25-year-old autodidact that likes to ponder. D...
# 51                                                 None
# 54    An online education company with coding and de...
# 56                                                 None
# 64    Blogging and podcasting about all things tech....
# 65                                                 None
# 69    This account is now inactive. For the latest f...
# 72    Empowering people to transform their lives by ...
# 77    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 78                                                 None
# 83    We are a talent and digital skills accelerator...
# 84                                                 None
# 88                                                 None
# 90    the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 105   An online education company with coding and de...
# 123   A tool to allow publications to better monetiz...
# 135   16-week intensive and part-time software devel...
# 144   I’m Leibel. I’m transitioning from Talmud to T...
# 146                                                None
# 150                                                None
# 154   Providing the 21st century CS degree. We turn ...
# 157                   Admin Situs Belajar Online Niomic
# ...                                                 ...
# 938   We're a 9-week iOS Training Lab and app develo...
# 940   the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 942   the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
# 944   Providing the 21st century CS degree. We turn ...
# 948   Somos la escuela de programación con los progr...
# 955   Full-Stack Developer. Thinkful grad. I like to...
# 960   The world’s top ranked immersive software engi...
# 961   Co-founder @ Le Wagon Montréal, a coding bootc...
# 966   Senior Software Engineer @teckro, Experienced ...
# 968                             New Fullstack Developer
# 976   Learning JavaScript, Vue.js, Sass, Python, Dja...
# 980   We transform #Veterans into software developer...
# 981                                                None
# 983   I’m Leibel. I’m transitioning from Talmud to T...
# 987                 Life too short we haffi cherish it.
# 988   Björn is an Entrepreneur, Web Developer and AI...
# 995   Providing the 21st century CS degree. We turn ...
# 1002  Full-Stack Developer. Thinkful grad. I like to...
# 1015  the Black MacGyver | @OURshow (Sat 5-7pm WPRK ...
#
# 72      medium  No Risk: Why You Should Only Attend a Coding S...
# 77      medium  Day 43 — Can’t Take That Awayliner notes: Yest...
# 78      medium  Be consistent, stay hungry It has been an even...
# 83      medium  Student Profile: Sam Maggs Coding Fellowship S...
# 84      medium  General Assembly, Web Development Immersive — ...
# 88      medium  Cali homie in N Y C So, I joined a coding boot...
# 90      medium  Day 59 — Last Callliner notes: Yesterday was a...
# 105     medium  Why do students choose Bloc? Alumni and curren...
# 123     medium  Hiring Technical Employees as a Non- Technical...
# 135     medium  How we got an app on the Play Store Armed with...
# 144     medium  My first app!! but first, a blogging refresh H...
# 146     medium  Coding Bootcamp vs. C S Degree Coding bootcamp...
# 150     medium  My First Ruby on Rails Project My First Ruby o...
# 154     medium  Why You Should Attend a Part- Time Online Codi...
# 157     medium  Belajar Pemrograman c++ Untuk Pemula Mari Bela...
# ...        ...                                                ...
# 938     medium  Codebase to award Savannah Student Innovator S...
# 940     medium  Day 58 — This is it!liner notes: Yesterday, mo...
# 942     medium  Day 44 — We’re Almost Thereliner notes: I thin...
# 944     medium  Going to Your First Hackathon? Read This. Wond...
# 948     medium  Garantía Cero Uno La educación en México está ...
# 955     medium  My Thinkful Halftime Report I cannot believe t...
# 960     medium  Early Coding School Dev Bootcamp Shuts Down — ...
# 961     medium  Stéphanie & Sara codent leur projet final (bat...
# 966     medium  I’ve also started an awesome list about coding...
# 968     medium  Stranger in a strange land… Not long ago I had...
# 976     medium  Java Script “ Call, Apply, Bind” J L’s Coding ...
# 980     medium  From Deployed to Deploying: 5 Similarities bet...
# 981     medium  General Assembly, Web Development Immersive — ...
# 983     medium  So that’s what R E S Tful means Ruby/ Rails da...
# 987     medium  “ Django girls made me a better girl”“ They sa...
# 988     medium  Virtual Box — fixing all the errors Lately, we...
# 995     medium  A Deep Dive into the R O I of Coding Bootcamps...
# 1002    medium  Documentation, Interviews, and Meetups This ha...
# 1015    medium  Day 20 — Own Lightliner notes:“ You ain’t got ...
# 1019    medium  This is It Well, I have officially quit my job...
# 1021    medium  The art of creating news to score some great t...
# 1024    medium  How to keep fit during a fast-paced coding boo...
# 1025    medium  A Swift Transition I thought that life would b...
# 1029    medium  Announcing the Alchemy Code Lab x W W Code Por...
# 1034    medium  Comment s’initier au code ? Vous souhaitez app...
# 1037    medium  General Assembly, Web Development Immersive — ...
# 1047    medium  Day 81 / Early to Riseliner notes: Professiona...
# 1053    medium  Project 1: Conquered On Friday, me and my team...
# 1058    medium  Day 45 - I'm so excitedliner notes: Yesterday ...
# 1059    medium  Java Script “ This” — Advanced J L’s Coding Bo...
#
#                                                    tags  \
# 2     [Story, My Life, Codingbootcamp, Coding, Startup]
# 14    [Reactjs, Firebase, Coding, Codingbootcamp, Hi...
# 23    [Codingbootcamp, JavaScript, Function, Front E...
# 28    [Data Science, Data, Codingbootcamp, Coding, W...
# 34    [Machine Learning, Codingbootcamp, Education, ...
# 43    [Programming, Meet The Instructor, Coding, Tec...
# 46    [Programming, Student Stories, Learning To Cod...
# 47    [JavaScript, Materialize, React, Hip Hop, Codi...
# 49    [Life Lessons, Failure, Codingbootcamp, Depres...
# 51    [Entrepreneurship, Startup, Technology, Coding...
# 54    [Coding Bootcamps, Education, Access Loan, Fin...
# 56    [Programming, Coding, Coding Bootcamps, Techno...
# 64    [Coding, Learn To Code, Code Newbie, Codingboo...
# 65    [Life Lessons, Codingbootcamp, Bugs, Programmi...
# 69    [Code School, Codingbootcamp, Learn To Code, I...
# 72    [Education, Coding, Codingbootcamp, Technology...
# 77      [React, Redux, Coding, Codingbootcamp, Hip Hop]
# 78    [Entrepreneurship, Coding, Codingbootcamp, Int...
# 83    [Web Development, Students, Coding, Learning T...
# 84    [Web Development, Codingbootcamp, Programming,...
# 88        [Programming, Codingbootcamp, Codesmith, NYC]
# 90     [Startup, Code, Codingbootcamp, Coding, Hip Hop]
# 105   [Partnership, Tips, Coding Bootcamp, Happy Alu...
# 123   [Startup, Founders, Software Development, Hiri...
# 135   [Android, Coding, Codingbootcamp, Learning To ...
# 144   [Web Development, Coding Dojo, Codingbootcamp,...
# 146   [Programming, Codingbootcamp, Code School, Com...
# 150   [Ruby on Rails, Rails, Web Development, Coding...
# 154   [Programming, Coding, Codingbootcamp, Remote W...
# 157    [Programming, Codingbootcamp, Coding, HTML, PHP]
# ...                                                 ...
# 938   [Education, Scholarship, Savannah, Codingbootc...
# 940   [Hip Hop, Coding, Code, Codingbootcamp, Hip Ho...
# 942     [React, Redux, Coding, Codingbootcamp, Hip Hop]
# 944   [Hackathons, Coding, Programming, Codingbootca...
# 948   [Codingbootcamp, Monterrey, Education, Softwar...
# 955   [Web Development, Codingbootcamp, Coding, Java...
# 960   [Devbootcamp, Programming, Codingbootcamp, Cod...
# 961   [Women In Tech, Technology, Codingbootcamp, In...
# 966     [Codingbootcamp, Programming, Learning To Code]
# 968   [Programming, Coding, Codingbootcamp, Personal...
# 976   [JavaScript, Codingbootcamp, Coding, Programmi...
# 980   [Veterans, Technology, Military, Coding, Codin...
# 981   [Web Development, Codingbootcamp, Coding, Prog...
# 983   [Programming, Ruby on Rails, Algorithms, Codin...
# 987     [Django, Girls, Coding, Codingbootcamp, Python]
# 988   [Linux, Virtualbox, Codingbootcamp, Switzerlan...
# 995   [Programming, Codingbootcamp, Coding, Career A...
# 1002  [JavaScript, Coding, Codingbootcamp, Sql, Nodejs]
# 1015  [Music, Brother Ali, Hip Hop, Coding, Codingbo...
# 1019  [Tech, Learning To Code, Codingbootcamp, Codin...
# 1021  [Programming, Le Wagon, Codingbootcamp, Coding...
# 1024                  [Health, Codingbootcamp, Workout]
# 1025  [Learning To Code, Codingbootcamp, Web Develop...
# 1029  [Tech, Code School, Learning, Education, Codin...
# 1034  [Code, Learning To Code, Formation Professionn...
# 1037  [Design, Web Development, Tech, Coding Bootcam...
# 1047   [Angular, Hip Hop, Code, Coding, Codingbootcamp]
# 1053   [Humor, Ironhack, Coding, Miami, Codingbootcamp]
# 1058   [Coding, Codingbootcamp, Hip Hop, Code, Orlando]
# 1034  https://medium.com/coding-days/comment-sinitie...
# 1037  https://medium.com/@kmodestas/general-assembly...
# 1047  https://medium.com/@conshus/day-81-early-to-ri...
# 1053  https://medium.com/@12gcharles/project-1-conqu...
# 1058  https://medium.com/@conshus/day-45-im-so-excit...
# 1059  https://medium.com/@j_lim_j/javascript-this-ad...
#
#                     lowercase author     first name   gender
# 2                    irsan sebastian          irsan  Unknown
# 14                           conshus        conshus  Unknown
# 23                               이상훈            이상훈  Unknown
# 28                      leibel hecht         leibel  Unknown
# 34                        d saunders              d  Unknown
# 43                        develop me        develop  Unknown
# 46                    altcademy team      altcademy  Unknown
# 47                           conshus        conshus  Unknown
# 49                 ilsmarie presilia       ilsmarie  Unknown
# 51                          horizons       horizons  Unknown
# 54                              bloc           bloc  Unknown
# 56                         anonymous      anonymous  Unknown
# 64                   venturi's voice      venturi's  Unknown
# 65                          smartzoe       smartzoe  Unknown
# 69                     turing school         turing  Unknown
# 72                       app academy            app  Unknown
# 77                           conshus        conshus  Unknown
# 78                              eazi           eazi  Unknown
# 83                        develop me        develop  Unknown
# 84                          modestas       modestas  Unknown
# 88                                 e              e  Unknown
# 90                           conshus        conshus  Unknown
# 105                             bloc           bloc  Unknown
# 123   hindsight technology solutions      hindsight  Unknown
# 135                         codeclan       codeclan  Unknown
# 144                     leibel hecht         leibel  Unknown
# 146                         horizons       horizons  Unknown
# 150                         c miller              c  Unknown
# 154                     hack reactor           hack  Unknown
# 157                   irra wulandari           irra  Unknown
# ...                              ...            ...      ...
# 938                    team codebase           team  Unknown
# 940                          conshus        conshus  Unknown
# 942                          conshus        conshus  Unknown
# 944                     hack reactor           hack  Unknown
# 948                          cerouno        cerouno  Unknown
# 955                      l.j. yockey           l.j.  Unknown
# 960                fullstack academy      fullstack  Unknown
# 961                         mg ayoub             mg  Unknown
# 966                  fanis despoudis          fanis  Unknown
# 968                      jehoshuah k      jehoshuah  Unknown
# 976                            j.lim          j.lim  Unknown
# 980                     code platoon           code  Unknown
# 981                         modestas       modestas  Unknown
# 983                     leibel hecht         leibel  Unknown
# 987                   nakuya bridget         nakuya  Unknown
# 988                  björn schmidtke          björn  Unknown
# 995                     hack reactor           hack  Unknown
# 1002                     l.j. yockey           l.j.  Unknown
# 1015                         conshus        conshus  Unknown
# 1019                     l.j. yockey           l.j.  Unknown
# 1021                   thirdeyemedia  thirdeyemedia  Unknown
# 1024                fredy-edwin esse    fredy-edwin  Unknown
# 1025                     l.j. yockey           l.j.  Unknown
# 1029                  women who code          women  Unknown
# 1034                     coding days         coding  Unknown
# 1037                        modestas       modestas  Unknown
# 1047                         conshus        conshus  Unknown
# 1053                giannini charles       giannini  Unknown
# 1058                         conshus        conshus  Unknown
# 1059                           j.lim          j.lim  Unknown
#
# [226 rows x 11 columns]

# %% [markdown]
# We can see that many of the authors in this part are different schools/workshops/organizations that we missed out on earlier, or they are more international type of names, or they are names with a letter for the first name followed by the full last name (these we may have to go through by hand in order to determine gender). Many are also from an author called "conshus"
